# %% [markdown]
# # Pandas

# %% [markdown]
# https://pandas.pydata.org/

# %% [markdown]
# ## 1. Series

# %%
import pandas as pd

# %%
pd.Series?

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
type(pd.Series(animals))
# Out:
# pandas.core.series.Series

# %%
numbers = [1, 2, 3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
sports = {'Archery': 'Bhutan', 'Golf': 'Scotland', 'Sumo': 'Japan', 'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taekwondo'], dtype='object')

# %%
list(s.index)
# Out:
# ['Archery', 'Golf', 'Sumo', 'Taekwondo']

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index=['India', 'America', 'Canada'])
s
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
# recordemos
sports
# Out:
# {'Archery': 'Bhutan',
#  'Golf': 'Scotland',
#  'Sumo': 'Japan',
#  'Taekwondo': 'South Korea'}

# %%
s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockey         NaN
# dtype: object

# %% [markdown]
# ### Selección por posición (índice: _i_) y por _label_: ".iloc" y ".loc"

# %%
sports
# Out:
# {'Archery': 'Bhutan',
#  'Golf': 'Scotland',
#  'Sumo': 'Japan',
#  'Taekwondo': 'South Korea'}

# %%
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Sumo']
# Out:
# 'Japan'

# %%
sports = {99: 'Bhutan', 100: 'Scotland', 101: 'Japan', 102: 'South Korea'}
s = pd.Series(sports)
s
# Out:
# 99          Bhutan
# 100       Scotland
# 101          Japan
# 102    South Korea
# dtype: object

# %%
s[0]  # OJO, genera error...
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-85465c0d638c> in <module>
# ----> 1 s[0]  # OJO, genera error...
#
# ...

# %%
s = pd.Series([1, 2, 3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.loc['Animal'] = 'Bear'
s
# Out:
# 0            1
# 1            2
# 2            3
# Animal    Bear
# dtype: object

# %%
s['Food'] = 'Pizza'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal     Bear
# Food      Pizza
# dtype: object

# %%
s.iloc[2] = 'entry'
s
# Out:
# 0             1
# 1             2
# 2         entry
# Animal     Bear
# Food      Pizza
# dtype: object

# %%
s = pd.Series([100, 120, 101, 3])
s
# Out:
# 0    100
# 1    120
# 2    101
# 3      3
# dtype: int64

# %%
import numpy as np

total = np.sum(s)
print(total)
# Out:
# 324

# %%
s = pd.Series(np.random.randint(0,1000,10000))
s
# Out:
# 0       301
# 1       820
# 2       267
# 3       790
# 4       470
#        ...
# 9995    173
# 9996     74
# 9997    932
# 9998    415
# 9999    274
# Length: 10000, dtype: int64

# %%
s.head()
# Out:
# 0    301
# 1    820
# 2    267
# 3    790
# 4    470
# dtype: int64

# %%
s.head(10)
# Out:
# 0    301
# 1    820
# 2    267
# 3    790
# 4    470
# 5    892
# 6    764
# 7    487
# 8    816
# 9    566
# dtype: int64

# %%
np.sum(s)
# Out:
# 5008695

# %%
s = s + 2
s.head()
# Out:
# 0    303
# 1    822
# 2    269
# 3    792
# 4    472
# dtype: int64

# %%
s+=2  # Muy común en Python (no lo habíamos usado antes)
s.head()
# Out:
# 0    305
# 1    824
# 2    271
# 3    794
# 4    474
# dtype: int64

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %% [markdown]
# # 2. DataFrames

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3])
df
# Out:
#     Name Item Purchased  Cost
# 0  Chris       Dog Food  22.5
# 1  Kevyn   Kitty Litter   2.5
# 2  Vinod      Bird Seed   5.0

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['Store 2']
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                      5
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['Store 1']
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
type(df.loc['Store 1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc[['Store 1', 'Store 2'], ['Cost', 'Name']]
# Out:
#          Cost   Name
# Store 1  22.5  Chris
# Store 1   2.5  Kevyn
# Store 2   5.0  Vinod

# %%
df.loc[('Store 1', 'Store 2'), ['Cost', 'Name']]  # funciona tanto con corchetes como con paréntesis
# Out:
#          Cost   Name
# Store 1  22.5  Chris
# Store 1   2.5  Kevyn
# Store 2   5.0  Vinod

# %% [markdown]
# Recomendación: utilizar el método loc con paréntesis para agrupar tanto filas como columnas:

# %%
df.loc[('Store 1', 'Store 2'), ('Cost', 'Name')]
# Out:
#          Cost   Name
# Store 1  22.5  Chris
# Store 1   2.5  Kevyn
# Store 2   5.0  Vinod

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df['Store 1']  # Ojo: indexación difiere entre Series y Dataframes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Store 1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-e90ad39c2f79> in <module>
# ...

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df['Name']
# Out:
# Store 1    Chris
# Store 1    Kevyn
# Store 2    Vinod
# Name: Name, dtype: object

# %%
df.loc[['Store 1', 'Store 2']][['Cost', 'Name']]  # ¿Notan la diferencia?
# Out:
#          Cost   Name
# Store 1  22.5  Chris
# Store 1   2.5  Kevyn
# Store 2   5.0  Vinod

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Cost                22.5           2.5          5

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2       5
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc['Store 1', ['Name', 'Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5

# %%
df.loc[:,['Name', 'Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
df.drop('Store 1')
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 2      Bird Seed   5.0

# %%
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %% [markdown]
# ### Unión de dataframes: _merge_

# %%
df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris         Sponge  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Filip          Spoon   5.0

# %%
df['Date'] = ['December 1', 'January 1', 'mid-May']
df
# Out:
#           Name Item Purchased  Cost        Date
# Store 1  Chris         Sponge  22.5  December 1
# Store 1  Kevyn   Kitty Litter   2.5   January 1
# Store 2  Filip          Spoon   5.0     mid-May

# %%
df['Delivered'] = True
df
# Out:
#           Name Item Purchased  Cost        Date  Delivered
# Store 1  Chris         Sponge  22.5  December 1       True
# Store 1  Kevyn   Kitty Litter   2.5   January 1       True
# Store 2  Filip          Spoon   5.0     mid-May       True

# %%
df['Feedback'] = ['Positive', None, 'Negative']
df
# Out:
#           Name Item Purchased  Cost        Date  Delivered  Feedback
# Store 1  Chris         Sponge  22.5  December 1       True  Positive
# Store 1  Kevyn   Kitty Litter   2.5   January 1       True      None
# Store 2  Filip          Spoon   5.0     mid-May       True  Negative

# %%
adf = df.reset_index()
adf
# Out:
#      index   Name Item Purchased  Cost        Date  Delivered  Feedback
# 0  Store 1  Chris         Sponge  22.5  December 1       True  Positive
# 1  Store 1  Kevyn   Kitty Litter   2.5   January 1       True      None
# 2  Store 2  Filip          Spoon   5.0     mid-May       True  Negative

# %%
adf['Date'] = pd.Series({0: 'December 1', 2: 'May 15'})
adf
# Out:
#      index   Name Item Purchased  Cost        Date  Delivered  Feedback
# 0  Store 1  Chris         Sponge  22.5  December 1       True  Positive
# 1  Store 1  Kevyn   Kitty Litter   2.5         NaN       True      None
# 2  Store 2  Filip          Spoon   5.0      May 15       True  Negative

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')

student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

# %%
staff_df
# Out:
#     Name            Role
# 0  Kelly  Director of HR
# 1  Sally  Course liasion
# 2  James          Grader

# %%
student_df
# Out:
#     Name       School
# 0  James     Business
# 1   Mike          Law
# 2  Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])

# %%
staff_df
# Out:
#     Name            Role           Location
# 0  Kelly  Director of HR       State Street
# 1  Sally  Course liasion  Washington Avenue
# 2  James          Grader  Washington Avenue

# %%
student_df
# Out:
#     Name       School              Location
# 0  James     Business  1024 Billiard Avenue
# 1   Mike          Law  Fraternity House #22
# 2  Sally  Engineering   512 Wilson Crescent

# %%
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])

# %%
staff_df
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader

# %%
student_df
# Out:
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# ## Ejercicio con datos reales

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [18.0, 10.0]
plt.style.use('ggplot')

# %% [markdown]
# Tomado de https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2

# %%
crimes = pd.read_csv('Crimes_2015.csv')

# %%
crimes
# Out:
#               ID Case Number                    Date                   Block  \
# 0       10201852    HY389096  01/01/2015 12:00:00 AM   008XX N MAPLEWOOD AVE
# 1       10060114    HY239140  01/01/2015 12:00:00 AM     069XX S CORNELL AVE
# 2       10210454    HY397301  01/01/2015 12:00:00 AM    049XX W WABANSIA AVE
# 3       10025440    HY214766  01/01/2015 12:00:00 AM         004XX E 80TH ST
# 4       10225520    HY412735  01/01/2015 12:00:00 AM  075XX S BLACKSTONE AVE
# ...          ...         ...                     ...                     ...
# 258508  10369351    HZ105321  12/31/2015 12:00:00 AM     0000X W RANDOLPH ST
# 258509  10365050    HZ100594  12/31/2015 12:00:00 AM      038XX N FREMONT ST
# 258510  10364335    HY556149  12/31/2015 12:00:00 AM       037XX W ARGYLE ST
# 258511  10371800    HZ106801  12/31/2015 12:00:00 AM       019XX N Hoyne Ave
# 258512  10364402    HY556328  12/31/2015 12:00:00 AM  051XX S BLACKSTONE AVE
#
#         IUCR                Primary Type  \
# ...

# %%
type(crimes)
# Out:
# pandas.core.frame.DataFrame

# %%
crimes.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10201852    HY389096  01/01/2015 12:00:00 AM   008XX N MAPLEWOOD AVE  2825
# 1  10060114    HY239140  01/01/2015 12:00:00 AM     069XX S CORNELL AVE  1751
# 2  10210454    HY397301  01/01/2015 12:00:00 AM    049XX W WABANSIA AVE  0266
# 3  10025440    HY214766  01/01/2015 12:00:00 AM         004XX E 80TH ST  1154
# 4  10225520    HY412735  01/01/2015 12:00:00 AM  075XX S BLACKSTONE AVE  1153
#
#                  Primary Type                              Description  \
# 0               OTHER OFFENSE                  HARASSMENT BY TELEPHONE
# 1  OFFENSE INVOLVING CHILDREN             CRIM SEX ABUSE BY FAM MEMBER
# 2         CRIM SEXUAL ASSAULT                                PREDATORY
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
# ...

# %%
crimes.head(2)
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10201852    HY389096  01/01/2015 12:00:00 AM  008XX N MAPLEWOOD AVE  2825
# 1  10060114    HY239140  01/01/2015 12:00:00 AM    069XX S CORNELL AVE  1751
#
#                  Primary Type                   Description  \
# 0               OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1  OFFENSE INVOLVING CHILDREN  CRIM SEX ABUSE BY FAM MEMBER
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0            APARTMENT   False      True  ...     1              24        26
# 1            RESIDENCE   False     False  ...     5              43        20
#
#    X Coordinate Y Coordinate  Year              Updated On   Latitude  \
# 0     1159250.0    1905420.0  2015  08/20/2015 04:17:37 PM  41.896198
# 1     1188551.0    1859284.0  2015  08/17/2015 03:03:40 PM  41.768946
#
#    Longitude                       Location
# 0 -87.690553  (41.896197984, -87.690552821)
# ...

# %%
crimes = pd.read_csv('Crimes_2015.csv', parse_dates=['Date'])

# %%
crimes
# Out:
#               ID Case Number       Date                   Block  IUCR  \
# 0       10201852    HY389096 2015-01-01   008XX N MAPLEWOOD AVE  2825
# 1       10060114    HY239140 2015-01-01     069XX S CORNELL AVE  1751
# 2       10210454    HY397301 2015-01-01    049XX W WABANSIA AVE  0266
# 3       10025440    HY214766 2015-01-01         004XX E 80TH ST  1154
# 4       10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE  1153
# ...          ...         ...        ...                     ...   ...
# 258508  10369351    HZ105321 2015-12-31     0000X W RANDOLPH ST  1150
# 258509  10365050    HZ100594 2015-12-31      038XX N FREMONT ST  0890
# 258510  10364335    HY556149 2015-12-31       037XX W ARGYLE ST  1320
# 258511  10371800    HZ106801 2015-12-31       019XX N Hoyne Ave  1153
# 258512  10364402    HY556328 2015-12-31  051XX S BLACKSTONE AVE  0810
#
#                       Primary Type                              Description  \
# ...

# %%
len(crimes)
# Out:
# 258513

# %%
crimes.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  2.585130e+05  258513.000000  258513.000000  258513.000000
# mean   1.012519e+07    1144.529169      11.215962      22.823653
# std    4.544760e+05     691.766183       6.911082      13.798851
# min    2.171400e+04     111.000000       1.000000       1.000000
# 25%    1.003057e+07     612.000000       6.000000      10.000000
# 50%    1.014404e+07    1023.000000      10.000000      23.000000
# 75%    1.025740e+07    1655.000000      16.000000      34.000000
# max    1.039775e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate      Year       Latitude  \
# count   258513.000000  2.510190e+05  2.510190e+05  258513.0  251019.000000
# mean        37.528971  1.164449e+06  1.885516e+06    2015.0      41.841456
# std         21.417773  1.644281e+04  3.115721e+04       0.0       0.085695
# min          1.000000  1.094231e+06  1.813897e+06    2015.0      41.644590
# ...

# %%
summary = crimes.describe(include='all').round(2).transpose()
summary
# Out:
# <ipython-input-107-e38e57186321>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   summary = crimes.describe(include='all').round(2).transpose()
#                        count  unique                            top    freq  \
# ID                    258513     NaN                            NaN     NaN
# Case Number           258513  258489                       HY259141       3
# Date                  258513  110516            2015-01-01 00:01:00      82
# Block                 258513   27414               001XX N STATE ST     765
# IUCR                  258513     329                           0820   24528
# Primary Type          258513      32                          THEFT   56867
# Description           258513     307                         SIMPLE   27294
# ...

# %%
summary.insert(1, 'missing', len(crimes) - summary['count'])
summary.insert(0, 'type', crimes.dtypes)
summary
# Out:
#                                 type   count missing  unique  \
# ID                             int64  258513       0     NaN
# Case Number                   object  258513       0  258489
# Date                  datetime64[ns]  258513       0  110516
# Block                         object  258513       0   27414
# IUCR                          object  258513       0     329
# Primary Type                  object  258513       0      32
# Description                   object  258513       0     307
# Location Description          object  258344     169     116
# Arrest                          bool  258513       0       2
# Domestic                        bool  258513       0       2
# Beat                           int64  258513       0     NaN
# District                       int64  258513       0     NaN
# Ward                           int64  258513       0     NaN
# Community Area                 int64  258513       0     NaN
# ...

# %%
crimes.head()
# Out:
#          ID Case Number       Date                   Block  IUCR  \
# 0  10201852    HY389096 2015-01-01   008XX N MAPLEWOOD AVE  2825
# 1  10060114    HY239140 2015-01-01     069XX S CORNELL AVE  1751
# 2  10210454    HY397301 2015-01-01    049XX W WABANSIA AVE  0266
# 3  10025440    HY214766 2015-01-01         004XX E 80TH ST  1154
# 4  10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE  1153
#
#                  Primary Type                              Description  \
# 0               OTHER OFFENSE                  HARASSMENT BY TELEPHONE
# 1  OFFENSE INVOLVING CHILDREN             CRIM SEX ABUSE BY FAM MEMBER
# 2         CRIM SEXUAL ASSAULT                                PREDATORY
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
crimes['Description']
# Out:
# 0                         HARASSMENT BY TELEPHONE
# 1                    CRIM SEX ABUSE BY FAM MEMBER
# 2                                       PREDATORY
# 3         FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4             FINANCIAL IDENTITY THEFT OVER $ 300
#                            ...
# 258508                          CREDIT CARD FRAUD
# 258509                              FROM BUILDING
# 258510                                 TO VEHICLE
# 258511        FINANCIAL IDENTITY THEFT OVER $ 300
# 258512                                  OVER $500
# Name: Description, Length: 258513, dtype: object

# %%
crimes.Description
# Out:
# 0                         HARASSMENT BY TELEPHONE
# 1                    CRIM SEX ABUSE BY FAM MEMBER
# 2                                       PREDATORY
# 3         FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4             FINANCIAL IDENTITY THEFT OVER $ 300
#                            ...
# 258508                          CREDIT CARD FRAUD
# 258509                              FROM BUILDING
# 258510                                 TO VEHICLE
# 258511        FINANCIAL IDENTITY THEFT OVER $ 300
# 258512                                  OVER $500
# Name: Description, Length: 258513, dtype: object

# %%
type(crimes['Description'])
# Out:
# pandas.core.series.Series

# %%
crimes['Description'].to_frame()
# Out:
#                                     Description
# 0                       HARASSMENT BY TELEPHONE
# 1                  CRIM SEX ABUSE BY FAM MEMBER
# 2                                     PREDATORY
# 3       FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4           FINANCIAL IDENTITY THEFT OVER $ 300
# ...                                         ...
# 258508                        CREDIT CARD FRAUD
# 258509                            FROM BUILDING
# 258510                               TO VEHICLE
# 258511      FINANCIAL IDENTITY THEFT OVER $ 300
# 258512                                OVER $500
#
# [258513 rows x 1 columns]

# %%
crimes['Description'].head()
# Out:
# 0                    HARASSMENT BY TELEPHONE
# 1               CRIM SEX ABUSE BY FAM MEMBER
# 2                                  PREDATORY
# 3    FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4        FINANCIAL IDENTITY THEFT OVER $ 300
# Name: Description, dtype: object

# %%
crimes['Description'].head().to_frame()
# Out:
#                                Description
# 0                  HARASSMENT BY TELEPHONE
# 1             CRIM SEX ABUSE BY FAM MEMBER
# 2                                PREDATORY
# 3  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4      FINANCIAL IDENTITY THEFT OVER $ 300

# %%
crimes['Description'][0:3]
# Out:
# 0         HARASSMENT BY TELEPHONE
# 1    CRIM SEX ABUSE BY FAM MEMBER
# 2                       PREDATORY
# Name: Description, dtype: object

# %%
crimes.loc[0:3, 'Description']
# Out:
# 0                    HARASSMENT BY TELEPHONE
# 1               CRIM SEX ABUSE BY FAM MEMBER
# 2                                  PREDATORY
# 3    FINANCIAL IDENTITY THEFT $300 AND UNDER
# Name: Description, dtype: object

# %% [markdown]
# **OJO!!! Sintaxis de indexación no equivale a sintaxis propia del método "loc".**

# %%
crimes[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-d1c0495118a2> in <module>
# ----> 1 crimes[0]
#
# ...

# %%
crimes.loc[2]
# Out:
# ID                                    10210454
# Case Number                           HY397301
# Date                       2015-01-01 00:00:00
# Block                     049XX W WABANSIA AVE
# IUCR                                      0266
# Primary Type               CRIM SEXUAL ASSAULT
# Description                          PREDATORY
# Location Description                 RESIDENCE
# Arrest                                   False
# Domestic                                  True
# Beat                                      2533
# District                                    25
# Ward                                        37
# Community Area                              25
# FBI Code                                    02
# X Coordinate                               NaN
# Y Coordinate                               NaN
# Year                                      2015
# Updated On              08/31/2015 03:43:09 PM
# Latitude                                   NaN
# ...

# %%
crimes.head()
# Out:
#          ID Case Number       Date                   Block  IUCR  \
# 0  10201852    HY389096 2015-01-01   008XX N MAPLEWOOD AVE  2825
# 1  10060114    HY239140 2015-01-01     069XX S CORNELL AVE  1751
# 2  10210454    HY397301 2015-01-01    049XX W WABANSIA AVE  0266
# 3  10025440    HY214766 2015-01-01         004XX E 80TH ST  1154
# 4  10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE  1153
#
#                  Primary Type                              Description  \
# 0               OTHER OFFENSE                  HARASSMENT BY TELEPHONE
# 1  OFFENSE INVOLVING CHILDREN             CRIM SEX ABUSE BY FAM MEMBER
# 2         CRIM SEXUAL ASSAULT                                PREDATORY
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
crimes[['Description','Community Area']]
# Out:
#                                     Description  Community Area
# 0                       HARASSMENT BY TELEPHONE              24
# 1                  CRIM SEX ABUSE BY FAM MEMBER              43
# 2                                     PREDATORY              25
# 3       FINANCIAL IDENTITY THEFT $300 AND UNDER              44
# 4           FINANCIAL IDENTITY THEFT OVER $ 300              43
# ...                                         ...             ...
# 258508                        CREDIT CARD FRAUD              32
# 258509                            FROM BUILDING               6
# 258510                               TO VEHICLE              14
# 258511      FINANCIAL IDENTITY THEFT OVER $ 300              22
# 258512                                OVER $500              41
#
# [258513 rows x 2 columns]

# %%
crimes.loc[:,('Description','Community Area')]
# Out:
#                                     Description  Community Area
# 0                       HARASSMENT BY TELEPHONE              24
# 1                  CRIM SEX ABUSE BY FAM MEMBER              43
# 2                                     PREDATORY              25
# 3       FINANCIAL IDENTITY THEFT $300 AND UNDER              44
# 4           FINANCIAL IDENTITY THEFT OVER $ 300              43
# ...                                         ...             ...
# 258508                        CREDIT CARD FRAUD              32
# 258509                            FROM BUILDING               6
# 258510                               TO VEHICLE              14
# 258511      FINANCIAL IDENTITY THEFT OVER $ 300              22
# 258512                                OVER $500              41
#
# [258513 rows x 2 columns]

# %%
crimes.loc[5:9,['Description','Community Area']]
# Out:
#                       Description  Community Area
# 5   AGG CRIM SEX ABUSE FAM MEMBER              28
# 6       AGG CRIMINAL SEXUAL ABUSE              27
# 7   AGG CRIM SEX ABUSE FAM MEMBER               4
# 8                       PREDATORY              43
# 9  SEXUAL EXPLOITATION OF A CHILD              49

# %%
crimes.iloc[3:5,0:2]
# Out:
#          ID Case Number
# 3  10025440    HY214766
# 4  10225520    HY412735

# %%
crimes.iloc[3:5,0:4]
# Out:
#          ID Case Number       Date                   Block
# 3  10025440    HY214766 2015-01-01         004XX E 80TH ST
# 4  10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE

# %%
crimes.iloc[9,6]
# Out:
# 'SEXUAL EXPLOITATION OF A CHILD'

# %%
crimes[crimes.Arrest == True]
# Out:
#               ID Case Number                Date                  Block  IUCR  \
# 29      10328772    HY519557 2015-01-01 00:00:00    037XX N RICHMOND ST  1582
# 58       9911130    HY100056 2015-01-01 00:00:00   011XX N LECLAIRE AVE  1477
# 60       9911113    HY100015 2015-01-01 00:00:00       101XX S LOWE AVE  0486
# 65       9993839    HY183887 2015-01-01 00:00:00     068XX S PAULINA ST  1541
# 67      10083956    HY272608 2015-01-01 00:00:00    0000X W TERMINAL ST  0820
# ...          ...         ...                 ...                    ...   ...
# 258482  10363668    HY555583 2015-12-30 22:40:00      016XX W NORTH AVE  0460
# 258483  10363662    HY555590 2015-12-30 22:40:00  047XX W FULLERTON AVE  4625
# 258485  10363810    HY555732 2015-12-30 22:45:00        003XX W 95TH ST  2024
# 258500  10363698    HY555606 2015-12-30 23:05:00       035XX N BROADWAY  0860
# 258506  10363707    HY555620 2015-12-30 23:45:00   076XX S PHILLIPS AVE  0560
#
# ...

# %%
crimes[crimes['Arrest'] == True].head()
# Out:
#           ID Case Number       Date                 Block  IUCR  \
# 29  10328772    HY519557 2015-01-01   037XX N RICHMOND ST  1582
# 58   9911130    HY100056 2015-01-01  011XX N LECLAIRE AVE  1477
# 60   9911113    HY100015 2015-01-01      101XX S LOWE AVE  0486
# 65   9993839    HY183887 2015-01-01    068XX S PAULINA ST  1541
# 67  10083956    HY272608 2015-01-01   0000X W TERMINAL ST  0820
#
#                   Primary Type                     Description  \
# 29  OFFENSE INVOLVING CHILDREN               CHILD PORNOGRAPHY
# 58           WEAPONS VIOLATION      RECKLESS FIREARM DISCHARGE
# 60                     BATTERY         DOMESTIC BATTERY SIMPLE
# 65                   OBSCENITY  SALE/DIST OBSCENE MAT TO MINOR
# 67                       THEFT                  $500 AND UNDER
#
#                           Location Description  Arrest  Domestic  ...  Ward  \
# 29                                   RESIDENCE    True     False  ...    33
# ...

# %%
crimes[crimes['Community Area'] < 5]
# Out:
#               ID Case Number                Date                  Block  IUCR  \
# 7       10348954    HY539840 2015-01-01 00:00:00    026XX W AGATITE AVE  1752
# 10      10225760    HY412902 2015-01-01 00:00:00      050XX N MARINE DR  0810
# 34      10245990    HY433843 2015-01-01 00:00:00    045XX N WOLCOTT AVE  2825
# 50      10104118    HY293012 2015-01-01 00:00:00      061XX N HOYNE AVE  0266
# 73      10134606    HY323202 2015-01-01 00:00:00      047XX N MALDEN ST  0266
# ...          ...         ...                 ...                    ...   ...
# 258414  10363582    HY555495 2015-12-30 20:29:00  061XX N MAPLEWOOD AVE  0910
# 258416  10364023    HY555852 2015-12-30 20:30:00   065XX N BOSWORTH AVE  0910
# 258430  10364026    HY555888 2015-12-30 21:00:00   055XX N ARTESIAN AVE  1320
# 258465  10363683    HY555621 2015-12-30 22:00:00    048XX N KENMORE AVE  0910
# 258487  10363746    HY555592 2015-12-30 22:50:00   065XX N GLENWOOD AVE  0520
#
# ...

# %%
crimes['Community Area'][crimes['Community Area'] < 5]
# Out:
# 7         4
# 10        3
# 34        4
# 50        2
# 73        3
#          ..
# 258414    2
# 258416    1
# 258430    4
# 258465    3
# 258487    1
# Name: Community Area, Length: 11910, dtype: int64

# %%
crimes['Community Area'][crimes['Community Area'] < 5].to_frame()
# Out:
#         Community Area
# 7                    4
# 10                   3
# 34                   4
# 50                   2
# 73                   3
# ...                ...
# 258414               2
# 258416               1
# 258430               4
# 258465               3
# 258487               1
#
# [11910 rows x 1 columns]

# %% [markdown]
# ### Group by

# %%
# Dada una columna, se puede "partir" una tabla en grupos
crimes50_by_community = crimes.head(50).groupby('Community Area')
crimes50_by_community

# %%
crimes50_by_community.groups
# Out:
# {3: [10], 4: [7, 34], 6: [16, 45], 7: [44], 10: [28], 15: [13], 16: [29], 19: [33], 22: [17, 32], 23: [15, 46], 24: [0, 37], 25: [2, 30], 27: [6, 20], 28: [5], 29: [48], 30: [31, 40, 41, 42, 47], 36: [24], 38: [26], 40: [11], 43: [1, 4, 8, 18], 44: [3, 43], 49: [9], 56: [36], 58: [19], 60: [12, 14], 61: [27], 63: [23], 66: [25, 35], 67: [38], 69: [22, 39, 49], 71: [21]}

# %%
crimes_by_community = crimes.groupby('Community Area')

# %%
crimes_by_community.groups
# Out:
# {1: [101, 143, 309, 397, 404, 472, 501, 520, 588, 641, 712, 723, 767, 979, 984, 1319, 1369, 1429, 1630, 1658, 2029, 2066, 2214, 2240, 2241, 2283, 2323, 2354, 2357, 2369, 2371, 2473, 2486, 2604, 2628, 2676, 2753, 3007, 3033, 3053, 3138, 3225, 3258, 3392, 3407, 3449, 3451, 3612, 3616, 3730, 3803, 3823, 3947, 4030, 4082, 4161, 4230, 4362, 4450, 4525, 4593, 4614, 4837, 4861, 4881, 4938, 4962, 4968, 5058, 5064, 5148, 5198, 5267, 5499, 5667, 5671, 5765, 5834, 5909, 6007, 6015, 6039, 6043, 6259, 6340, 6430, 6693, 6769, 6934, 7155, 7200, 7311, 7329, 7335, 7343, 7561, 7631, 7682, 7730, 7758, ...], 2: [50, 475, 494, 586, 688, 784, 831, 1007, 1220, 1236, 1312, 1334, 1518, 1581, 1590, 1607, 1715, 1831, 1836, 1870, 1978, 1989, 2125, 2184, 2234, 2236, 2243, 2485, 2494, 2631, 2638, 2652, 2722, 2758, 2799, 2855, 2932, 2955, 3092, 3147, 3236, 3332, 3415, 3420, 3440, 3481, 3579, 3679, 3714, 3939, 4093, 4282, 4407, 4492, 4558, 4568, 4600, 4814, 4834, 4942, 5008, 5213, 5375, 5493, 5521, 5542, 5565, 5603
# ...

# %% [markdown]
# ### Aggregate ('agg')

# %% [markdown]
# Podemos "agregar" una columna a lo largo de los grupos, utilizando una "función de agregación".
# - Hay funciones predefinidas, como 'sum', 'mean', 'mode', 'count', 'std', 'unique'.
# - También se puede aplicar con funciones arbitarias definidas por el usuario.

# %%
community_crime_count = crimes_by_community['ID'].agg('count')
community_crime_count
# Out:
# Community Area
# 1     3519
# 2     3059
# 3     3585
# 4     1747
# 5     1375
#       ...
# 73    3109
# 74     608
# 75    2052
# 76    1622
# 77    2209
# Name: ID, Length: 77, dtype: int64

# %%
community_crime_count.to_frame()
# Out:
#                   ID
# Community Area
# 1               3519
# 2               3059
# 3               3585
# 4               1747
# 5               1375
# ...              ...
# 73              3109
# 74               608
# 75              2052
# 76              1622
# 77              2209
#
# [77 rows x 1 columns]

# %%
community_crime_count.plot(kind='bar');

# %% [markdown]
# ### Serie de tiempo

# %%
crimes.head()
# Out:
#          ID Case Number       Date                   Block  IUCR  \
# 0  10201852    HY389096 2015-01-01   008XX N MAPLEWOOD AVE  2825
# 1  10060114    HY239140 2015-01-01     069XX S CORNELL AVE  1751
# 2  10210454    HY397301 2015-01-01    049XX W WABANSIA AVE  0266
# 3  10025440    HY214766 2015-01-01         004XX E 80TH ST  1154
# 4  10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE  1153
#
#                  Primary Type                              Description  \
# 0               OTHER OFFENSE                  HARASSMENT BY TELEPHONE
# 1  OFFENSE INVOLVING CHILDREN             CRIM SEX ABUSE BY FAM MEMBER
# 2         CRIM SEXUAL ASSAULT                                PREDATORY
# 3          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
crimes['Date']
# Out:
# 0        2015-01-01
# 1        2015-01-01
# 2        2015-01-01
# 3        2015-01-01
# 4        2015-01-01
#             ...
# 258508   2015-12-31
# 258509   2015-12-31
# 258510   2015-12-31
# 258511   2015-12-31
# 258512   2015-12-31
# Name: Date, Length: 258513, dtype: datetime64[ns]

# %%
crimes['Day'] = crimes['Date'].dt.day
crimes
# Out:
#               ID Case Number       Date                   Block  IUCR  \
# 0       10201852    HY389096 2015-01-01   008XX N MAPLEWOOD AVE  2825
# 1       10060114    HY239140 2015-01-01     069XX S CORNELL AVE  1751
# 2       10210454    HY397301 2015-01-01    049XX W WABANSIA AVE  0266
# 3       10025440    HY214766 2015-01-01         004XX E 80TH ST  1154
# 4       10225520    HY412735 2015-01-01  075XX S BLACKSTONE AVE  1153
# ...          ...         ...        ...                     ...   ...
# 258508  10369351    HZ105321 2015-12-31     0000X W RANDOLPH ST  1150
# 258509  10365050    HZ100594 2015-12-31      038XX N FREMONT ST  0890
# 258510  10364335    HY556149 2015-12-31       037XX W ARGYLE ST  1320
# 258511  10371800    HZ106801 2015-12-31       019XX N Hoyne Ave  1153
# 258512  10364402    HY556328 2015-12-31  051XX S BLACKSTONE AVE  0810
#
#                       Primary Type                              Description  \
# ...

# %%
crimes_by_day = crimes.groupby('Day')

# %%
crimes_by_day['ID'].agg('count')
# Out:
# Day
# 1     9758
# 2     8559
# 3     8463
# 4     8273
# 5     8380
# 6     8517
# 7     8325
# 8     8130
# 9     8156
# 10    8390
# 11    8504
# 12    8639
# 13    8617
# 14    8773
# 15    8927
# 16    8796
# 17    8626
# 18    8390
# 19    8453
# 20    8866
# 21    8494
# 22    8520
# 23    8725
# 24    8437
# 25    8265
# 26    8394
# 27    8382
# 28    8250
# 29    7620
# 30    7705
# 31    4179
# Name: ID, dtype: int64

# %%
crimes_by_day['ID'].agg('count').plot(kind='bar');

# %% [markdown]
# Serie de tiempo solo para el Community Area 41:

# %%
crimes[crimes['Community Area'] == 41].groupby('Day')['ID'].agg('count').plot(kind='bar');

# %% [markdown]
# ### Multiple Group By

# %%
crimes_by_community_day = crimes.groupby(['Community Area', 'Day'])

# %%
crimes_by_community_day_count = crimes_by_community_day['ID'].agg('count')
crimes_by_community_day_count
# Out:
# Community Area  Day
# 1               1      151
#                 2      119
#                 3      112
#                 4      113
#                 5      114
#                       ...
# 77              27      66
#                 28      77
#                 29      64
#                 30      65
#                 31      47
# Name: ID, Length: 2387, dtype: int64

# %% [markdown]
# Parra arrestos, por ejemplo, podemos calcular el cociente.

# %%
crimes_by_community_day_arrests = crimes_by_community_day['Arrest'].agg('sum')
crimes_by_community_day_arrests
# Out:
# Community Area  Day
# 1               1      28
#                 2      26
#                 3      29
#                 4      27
#                 5      28
#                        ..
# 77              27     18
#                 28     19
#                 29     12
#                 30      7
#                 31      6
# Name: Arrest, Length: 2387, dtype: int64

# %%
community_day_arrest_prop = crimes_by_community_day_arrests / crimes_by_community_day_count
community_day_arrest_prop
# Out:
# Community Area  Day
# 1               1      0.185430
#                 2      0.218487
#                 3      0.258929
#                 4      0.238938
#                 5      0.245614
#                          ...
# 77              27     0.272727
#                 28     0.246753
#                 29     0.187500
#                 30     0.107692
#                 31     0.127660
# Length: 2387, dtype: float64

# %%
type(community_day_arrest_prop)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### "Unstacking"

# %%
community_arrest_timeseries = community_day_arrest_prop.unstack('Community Area')
community_arrest_timeseries
# Out:
# Community Area        1         2         3         4         5         6   \
# Day
# 1               0.185430  0.152174  0.223776  0.152778  0.118644  0.207254
# 2               0.218487  0.174312  0.290323  0.177778  0.035714  0.154762
# 3               0.258929  0.220000  0.324074  0.164179  0.058824  0.112994
# 4               0.238938  0.166667  0.261905  0.169811  0.100000  0.124294
# 5               0.245614  0.242424  0.250000  0.169492  0.092593  0.209459
# 6               0.215385  0.162393  0.232759  0.098039  0.209302  0.187192
# 7               0.245455  0.242718  0.264151  0.185714  0.102041  0.204301
# 8               0.204545  0.175439  0.283333  0.125000  0.083333  0.197740
# 9               0.223140  0.190476  0.192308  0.268657  0.159091  0.146067
# 10              0.245098  0.200000  0.319672  0.157895  0.134615  0.201087
# 11              0.312000  0.111111  0.281250  0.188679  0.163265  0.136612
# ...

# %%
community_arrest_timeseries[[40,41,42]].plot();

# %%
community_arrest_timeseries.plot();

# %% [markdown]
# ----
