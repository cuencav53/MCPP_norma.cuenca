# %% [markdown]
# # Prácticas con While, For, If en Python:

# %% [markdown]
# 1. Escriba un programa que pida dos números enteros. El programa pedirá de nuevo el segundo número mientras no sea mayor o igual que el primero. El programa terminará escribiendo los dos números.

# %%
primero= input( "Digame un número: ")
segundo= input("Digame otro número mayor que el anterior: " )
if segundo > primero: 
    print( "sus numeros fueron", primero, "y", segundo)
# Out:
# Digame un número: 5
# Digame otro número mayor que el anterior: 8
# Sus numeros fueron: 5 y 8

# %%
# Out:
# NÚMERO MAYOR
# Escriba un número: 4
# Escriba un número mayor que {primero}: 2
# 2 no es mayor que 4. Inténtelo de nuevo: 7
#
# Los números que ha escrito son 4 y 7.

# %% [markdown]
# 2. Escriba un programa que pida la anchura de un triángulo y lo dibuje con caracteres producto (*)

# %%
# Out:
# Digame la anchura: 5
#
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# 3. Escriba un programa que pida dos números enteros y que calcule su división, escribiendo si la división es exacta o no.

# %%
# Out:
# División
# Escriba un número entero: 6
# Escriba otro número entero: 2
# La división es exacta: el residuo de la operación es igual a 0. El cociente de la operación es 6/2 = 3.0.

# %%
# Out:
# Escriba el dividendo: 6
# Escriba el divisor: 3
# La división es exacta. Cociente: 2

# %% [markdown]
# 4. Escriba un programa que pida el año actual y un año cualquiera y que escriba cuántos años han pasado desde ese año o cuántos años faltan para llegar a ese año.

# %%
# Out:
# ¿En qué año estamos?: 2020
# Esriba un año cualquiera: 2020
# Es el mismo año, por favor madure
# Esriba un año cualquiera: 2020
# Es el mismo año, por favor madure
# Esriba un año cualquiera: 2021
# Faltan 1 años para llegar al 2021

# %%
# Out:
# Indique el año actual:2020
# Indique otro año:2021
# Falta 1 año para 2021

# %% [markdown]
# 5. Desarrolle un rubí cuando se le pida al usuario introducir una anchura determinada:

# %%
# Out:
# Magnitud del Rubí: 10
#
#           *
#          * *
#         * * *
#        * * * *
#       * * * * *
#      * * * * * *
#     * * * * * * *
#    * * * * * * * *
#   * * * * * * * * *
#  * * * * * * * * * *
#   * * * * * * * * *
#    * * * * * * * *
#     * * * * * * *
#      * * * * * *
#       * * * * *
#        * * * *
#         * * *
#          * *
#           *
