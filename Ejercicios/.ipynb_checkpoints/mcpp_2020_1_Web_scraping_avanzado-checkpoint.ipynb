# %% [markdown]
# <h1>Web scraping: Temas avanzados</h1>

# %% [markdown]
# **Por Daniel Rojas**

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://www.stratkom.se/wp-content/uploads/2016/06/computer-programming-1024x683.jpeg")
# Out:
# <img src="https://www.stratkom.se/wp-content/uploads/2016/06/computer-programming-1024x683.jpeg"/>

# %% [markdown]
# <br>
# <br>
#
# -  La clase pasada aprendimos como realizar web scraping básico utilizando la librería ***Beautiful Soup***
#
#
#
# -  ***Beautiful Soup*** por sí solo es bastante poderoso cuando nuestra página web objetivo está escrita en lenguaje ***HTML***

# %% [markdown]
# Sin embargo, hoy en día es más común encontrar páginas web cuya estructura esté hecha en ***HTML*** pero sus interacciones sean mostradas por medio de ***JavaScript***
#
#
#
# ## ¿Cuál es la diferencia entre HTML y JavaScript?
#
#
# ### HTML: Estructura / JavaScript: Movimiento

# %%
Image(url= "https://media.giphy.com/media/gZsjswrzG3IL6/giphy.gif")
# Out:
# <img src="https://media.giphy.com/media/gZsjswrzG3IL6/giphy.gif"/>

# %% [markdown]
# <br>
#
# -  ¿Porqué queremos ***movimiento*** en una página web?
#
#
# -  Para que exista mayor interacción y los elementos no estén estáticos
#
#
# ## Ejemplos
#
#
# -  [Twitter](http://twitter.com)
# -  [URosario](http://urosario.edu.co)
#
#
# <br>
#
#
# -  **OJO! en este tipo de páginas web, utilizar solamente *Beautiful Soup* no es suficiente a la hora de hacer Web scraping**
#
#
# -  Cuando una web está escrita en JavaScript el buscador realiza un proceso llamado ***Rendering*** que consiste en *ejecutar* el código JavaScript de la página
#
#
# -  ¿Cuál es el problema?... SOLO los navegadores pueden hacer ***Rendering*** (Chrome, Firefox, Safari, Explorer)
#
#
# -  ***Beautiful Soup*** y ***urllib*** NO le permiten a Python realizar este proceso
#
#
# -  Es decir, el código HTML retornado estará incompleto y probablemente la información que necesitemos no estará presente
#
#
# ## Ejemplo
#
#
# -  [Twitter](http://twitter.com)
#
#
#
# ## ¿Cómo hacer web scraping de páginas escritas en JavaScript?
#
#
#
# ### Lo que necesitaremos:
#
# - Python 3
#
#
# - Beautiful Soup
#
#
# - [Selenium](http://selenium-python.readthedocs.io/)
#
#
# - [PhantomJS](http://phantomjs.org/)

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# Definimos nuestro url

url = "https://www.davivienda.com/wps/portal/personas/nuevo"

# %% [markdown]
# Veamos que pasaría si utilizamos urllib y Beautiful Soup

# %%
from urllib.request import urlopen

webpage = urlopen(url) 

soup = BeautifulSoup(webpage, "html.parser")

print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><link href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" rel="icon" type="image/x-icon"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/normalize.css" rel="stylesheet"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/estilos-wps9.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/s-pagos-pse.css" rel="stylesheet" type="text/css"/>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/modernizr.js" type="text/javascript"></script>
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - INICIO -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/easyXDM.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/openIframe.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/openIframe.js"></script>-->
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - FIN -->
# <!-- Can run Adserver validation -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/ads.min.js"></script>
# <!-- End run Adserver validation -->
# <script type="text/javascript">
#
#     var divAdserverId = 'div-gpt-ad-1499960009335-0';
#       var getGpt = false;
#       var isMobile = false; //initiate as false
#       // device detection
#       if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|ipad|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(navigator.userAgent) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(navigator.userAgent.substr(0,4)))
#         isMobile = true;
#
#       function iframeHeight(height) {
#         $('#ifrm-contenedor').height(height + 100);
#       }
#       function mostrarBtnCerrarFooter () {
#         $('a.btn-cerrar-footer').css('top','');
#         $('a.btn-cerrar-footer').css('top','-30px;');
#       }
#       $(document).on("ready",function(){
#         $("#row_8").css("display","none");
#       });
#     var gtmFn = function () {
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGtm = $.ajax({
#         type:'GET',
#         url:'https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5',
#         data:null,
#         timeout: 1000,
#         success:function(){
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-WVX9Z5');
#         adserverFn();
#         },
#       error: function(xmlhttprequest, textstatus, message) {
#         if(textstatus==="timeout") {
#           console.error("cannot load GTM libs");
#           element.css('background-image', 'url(' + image + ')');
#         } else {
#           console.error("something happened and cannot load GTM libs");
#         }
#       },
#         dataType:'script'
#       });
#
#     };
#     var adserverFn = function(){
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGpt = $.ajax({
#       type:'GET',
#         url:'https://www.googletagservices.com/tag/js/gpt.js',
#         data:null,
#           timeout: 1000,
#         success:function(){
#          getGpt = true;
#          console.debug("success callback exec");
#         },
#         error: function(xmlhttprequest, textstatus, message) {
#           if(textstatus==="timeout") {
#               console.error("cannot load Adserver libs");
#         console.log(xmlhttprequest);
#         console.log(message);
#               element.css('background-image', 'url(' + image + ')');
#           } else {
#               console.error("something happened and cannot load Adserver libs");
#           }
#         },
#         dataType:'script'
#       });
#       var googletag = googletag || {};
#     var matriz =[[1366,768 ],[1920,1080],[1600,900 ],[1440,900 ],[1280,800 ],[1280,1024],[1360,768 ],[1024,768 ],[1280,720 ],[1536,864 ],[1680,1050],[1093,615 ],[2560,1440],[1280,768 ],[1024,600 ],[360,640  ],[1920,1200],[1093,614 ],[1152,720 ],[1152,864 ],[1301,731 ],[1024,820 ],[1438,808 ],[1280,960 ],[1518,853 ],[1242,698 ],[1344,840 ],[1607,904 ]];
#     var idx = -1;
#     var ancho=0;
#     var alto=0;
#     for (i = 0; i < matriz.length; i++) {
#       ancho=parseInt(matriz[i][0]);
#       alto = parseInt(matriz[i][1]);
#       if (ancho ==parseInt(screen.width) && alto ==parseInt(screen.height)){
#         idx= 0;
#          break;
#       }
#     }
#       googletag.cmd = googletag.cmd || [];
#
#       if( window.canRunAds === true ){
#     if (idx !=  -1){
#         ajaxGpt.then(function(){
#         console.debug("then ajaxGpt callback exec");
#             banner.empty();
#         banner.append("<div id='" + divAdserverId + "' ></div>");
#       var elementAds = $( '#'+divAdserverId );
#       elementAds.find('div').css("height", window.innerHeight);
#       elementAds.find('div').css("width", window.innerWidth);
#       elementAds.find('iframe').css("height", window.innerHeight);
#       elementAds.find('iframe').css("width", window.innerWidth);
#         });
#       }else{
#         element.css('background-image', 'url(' + image + ')');
#       }
#     }
#     else{
#         element.css('background-image', 'url(' + image + ')');
#     }
#     };
#    </script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   </script>
# <script>
#     googletag.cmd.push(function() {
#
#
#       /* DEFINE SLOT */
#       googletag.defineSlot('/236880650/Home_Daviviendacombanner', [screen.width,screen.height], divAdserverId).addService(googletag.pubads()).
#       addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.enableServices();
#       });
#       googletag.cmd.push(function() { googletag.display(divAdserverId);});
#
#
#   </script>
# </head>
# <body onload="gtmFn()">
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="auto !important" src="https://www.googletagmanager.com/ns.html?id=GTM-WVX9Z5" style="display:none;visibility:hidden" width="100%"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- JPG - LOADING SCREEN - INICIO -->
# <div class="loadingScreen">
# <img src="/PersonasDaviviendaNewTheme/resources/img/iconos/loadingScreenIcon.gif"/>
# </div>
# <!-- JPG - LOADING SCREEN - FIN -->
# <header>
# <div class="login">
# <div class="wrap">
# <div class="form" style="width:100%;padding:0px;">
# <div id="divIFrame" style="border:none;overflow:hidden;height: 310px; width: 100%;display:block;">
# </div>
# <a class="btn-cerrar" href="#" id="personas-cerrar-ingresar" title="Cerrar"><i class="icono-cerrar"></i></a>
# </div>
# </div>
# </div>
# <div class="cabecera">
# <div class="wrap container">
# <div class="four columns">
# <a class="current" href="/wps/portal/personas/nuevo" id="personas-volver-head" title="Volver a Home personas"><h1>Davivienda</h1></a>
# </div>
# <div class="three columns">
# <div class="tipo-acceso">
# <nav class="acceso">
# <ul>
# <li>
# <a class="activo" href="#" title="Personas">
# <i class="icono personas"></i>Personas</a><img class="img_indicador" src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-indicador.png"/>
# </li>
# <li>
# <a href="/wps/portal/empresas/nuevo" id="empresas-volver-head" title="Empresas">
# <i class="icono empresas"></i>Empresas
#                     </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <!--tipo-acceso-->
# <div class="three columns column-info-corporativa">
# <!-- Escritorio -->
# <div class="info-corporativa info-corporativa-desktop">
# <ul>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li>
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# <!-- Móvil -->
# <div class="info-corporativa info-corporativa-mobile">
# <ul class="gallery js-flickity" data-flickity-options='{ "wrapAround": false }'>
# <li class="gallery-cell">
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li class="gallery-cell">
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li class="gallery-cell">
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="two columns column-despliegue-login">
# <div class="despliegue-login">
# <a class="mostrar-login" href="#" id="personas-ingresar" onclick="openIframe('https://transacciones.davivienda.com/transaccional/personas/nuevo/login.jsf');abrirPopUpSeguridad(); event.preventDefault();" title="Ingresar"><i class="icono login"></i>Ingreso
#                 <br/>Clientes
#               </a>
# </div>
# </div>
# <!--despliegue-login-->
# </div>
# <div class="aqui-puedo">
# <div class="wrap container">
# <a class="desplegar-aqui-puedo" href="#" id="desplegable-aqui-puedo" title="Aquí puedo">
# </a>
# <div class="buscador">
# <!-- Mostrar Enlace en lugar de Input -->
# <a href="/wps/portal/personas/nuevo/personas/Atencionenlinea" id="BtnAtencionenlinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_atencion_linea_nuevo" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Atención en línea</span>
# </a>
# <a href="/wps/portal/personas/nuevo/personas/aqui_puedo/pagar_facilmente/pse/" id="BtnPagosEnLinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_pagos_en_linea_PSE" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Pagos en línea y PSE</span>
# </a>
# </div>
# </div>
# <nav class="aqui-puedo">
# <!-- <a rel="dynamic-content" href="dyn-cs:id:ThemePersonas_tabNav"></a> -->
# <!--SESSION COOKIE-->
# <div class="wrap menu" style="max-width:1170px; width: 100%;">
# <!--menú normal -->
# <div id="iterator_menu"></div>
# <!--menú responsive-->
# <div class="accordion" id="responsive_menu">
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# 																				Construir mi futuro
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																							Vivienda
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																							Vehículo
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																							Inversiones
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																							Pensión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																							Educación
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																							Ahorros
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1065">
# 																				Manejar mi dinero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1065">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																							Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																							Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																							Planeación de Impuestos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																							Tarjetas Débito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																							Giros Directos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																							Giros internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# 																				Alcanzar lo que quiero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																							Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																							Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																							Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																							Crédito Fractionals
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																							Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# 																				Comprar lo que deseo
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																							Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																							Mundo Diners
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																							Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																							Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																							Compras virtuales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# 																				Respaldar a mi familia
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																							Portafolio Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																							Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																							Cuenta Niños
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																							Tarjeta Mujer
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																							Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# 																				Administrar mis inversiones
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																							Davivienda Colombia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																							Davivienda Panamá
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																							Davivienda Miami
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																							Davivienda Corredores
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																							Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GE7">
# 																				Proteger mi patrimonio
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GE7">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																							Seguros para Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																							Seguros para Bienes
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																							Seguros para Casa
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																							Seguros para Carro
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																							Asistencias
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G96">
# 																				Pagar fácilmente
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G96">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																							Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																							Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																							Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																							Transferencias Automaticas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS4" id="menu-personas-comprar-con-codigo-qr" onclick="var nm='Comprar con código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Comprar con código QR">
# 																							Comprar con código QR
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS5" id="menu-personas-vender-con-codigo-qr" onclick="var nm='Vender con Código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vender con Código QR">
# 																							Vender con Código QR
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div id="cnt" style="display:none;">
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono casa"></i>
# 																					Construir mi futuro
# 																				</li>
# <li style="height: auto;">Paso a paso le ayudamos en el Crecimiento de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																						Vivienda
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																						Vehículo
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																						Inversiones
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																						Pensión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																						Educación
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																						Ahorros
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono dinero"></i>
# 																					Manejar mi dinero
# 																				</li>
# <li style="height: auto;">Desde una cuenta de ahorros hasta un portafolio completo de servicios.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																						Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																						Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																						Planeación de Impuestos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																						Tarjetas Débito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																						Giros Directos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																						Giros internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono compra"></i>
# 																					Alcanzar lo que quiero
# 																				</li>
# <li style="height: auto;">Crédito de consumo que se adapta a sus necesidades.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																						Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																						Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																						Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																						Crédito Fractionals
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																						Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono tarjeta"></i>
# 																					Comprar lo que deseo
# 																				</li>
# <li style="height: auto;">Las Tarjetas de Crédito Davivienda le sirven para todo incluso para comprar.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																						Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																						Mundo Diners
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																						Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																						Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																						Compras virtuales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono familia"></i>
# 																					Respaldar a mi familia
# 																				</li>
# <li style="height: auto;">Productos pensandos para apoyar a los que más quiere.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																						Portafolio Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																						Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																						Cuenta Niños
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																						Tarjeta Mujer
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																						Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono grafico"></i>
# 																					Administrar mis inversiones
# 																				</li>
# <li style="height: auto;">Banca Patrimonial, una asesoría profesional en el manejo de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																						Davivienda Colombia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																						Davivienda Panamá
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																						Davivienda Miami
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																						Davivienda Corredores
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																						Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono proteger"></i>
# 																					Proteger mi patrimonio
# 																				</li>
# <li style="height: auto;">Aquí le ayudamos a asegurar todo lo que ha construido.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																						Seguros para Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																						Seguros para Bienes
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																						Seguros para Casa
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																						Seguros para Carro
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																						Asistencias
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono pagar"></i>
# 																					Pagar fácilmente
# 																				</li>
# <li style="height: auto;">Realice de forma sencilla el pago de sus obligaciones.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																						Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																						Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																						Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																						Transferencias Automaticas
# 																						</a>
# </li>
# <li class="list-cnt">
# ...
# <!-- LINKS divItemInferiorM RESPALDO -->
# <div class="divItemInferiorM-respaldo" style="display:none;">
# <ul class="opciones-usuario">
# <li><a href="https://daviplata.com" title="Inicio"><i class="icon-ap ico-conocer"></i>Conocer <span>DaviPlata</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/Educacion_Financiera/" title="Inicio"><i class="icon-ap ico-aprender"></i>Educación  <span>Financiera</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/asesorarme_si_vivo_o_viajo_al_exterior/" title="Inicio"><i class="icon-ap ico-asesorame"></i>Asesorarme <span>si vivo o viajo al exterior</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor" title="Inicio"><i class="icon-ap ico-aprender"></i>Defensor del  <span>consumidor financiero</span></a></li>
# </ul>
# </div>
# <script type="text/javascript">
#     $(function() {
#         var opcionesUsuario = $('#divItemInferiorM').children('ul');
#         if (typeof opcionesUsuario === "undefined") {
#         	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#         } else {
#           	if ( opcionesUsuario.length <= 0 ) {
#             	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#           	}
#         }
#     });
# </script>
# <script type="text/javascript">
#
# function abrirPopUpSeguridad(){
#
#     var IE = 9
#     var MZ = 14
#     var GC = 41
#
# 	var browser = get_browser_info();
#
# 	/*Internet Explorer*/
# 	if (navigator.userAgent.indexOf('MSIE') !=-1 && browser.version >= IE) {
# 	    abrirPopUp();
# 	}
# 	/*Mozilla Firefox*/
# 	else if (navigator.userAgent.indexOf('Firefox') !=-1 && browser.version >= MZ) {
# 		abrirPopUp();
# 	}
# 	/*Google Chrome*/
# 	else if (navigator.userAgent.indexOf('Chrome') !=-1 && browser.version >= GC) {
# 		abrirPopUp();
# 	}
#
# };
#
# function get_browser_info(){
#     var ua=navigator.userAgent,tem,M=ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#     if(/trident/i.test(M[1])){
#         tem=/\brv[ :]+(\d+)/g.exec(ua) || [];
#         return {name:'IE',version:(tem[1]||'')};
#         }
#     if(M[1]==='Chrome'){
#         tem=ua.match(/\bOPR\/(\d+)/);
#         if(tem!=null)   {return {name:'Opera', version:tem[1]};}
#         }
#     M=M[2]? [M[1], M[2]]: [navigator.appName, navigator.appVersion, '-?'];
#     if((tem=ua.match(/version\/(\d+)/i))!=null) {M.splice(1,1,tem[1]);}
#     return {
#       name: M[0],
#       version: M[1]
#     };
# }
#
# var notificacion = false;
#
# function abrirPopUp(){
#     if (!isMobile) {
#     	/*var scroll = 0;
#     	$('div.contenedor-ifrm-popup-seguridad').bPopup({
#     		position: ['auto', scroll ],
#     		positionStyle: 'fixed'
# 	});*/
# }}
#
# </script>
# </link></div>
# </section> </div>
# </td>
# </tr>
# <tr>
# <td style="width:100%;" valign="top">
# <div class="component-control id-Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"><span id="Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"></span><section class="ibmPortalControl wpthemeNoSkin a11yRegionTarget" role="region">
# <!-- marks the node the analytics tags for this portlet will be placed in -->
# <div class="asa.portlet" id="asa.portlet.Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1" style="display:none;">
# <span class="asa.portlet.id">Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1</span>
# </div>
# <!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# <div style="position:relative; z-index: 1;">
# <div class="analytics.overlay"></div>
# </div>
# <!-- Hide the text of the title, but still provide the lm-dynamic-title container for accessing the dynamic title -->
# <span class="wpthemeAccess">
# <span class="lm-dynamic-title asa.portlet.title a11yRegionLabel"><span dir="ltr" lang="en">Web Content Viewer</span></span>
# </span>
# <div class="wpthemeOverflowAuto"> <!-- lm:control dynamic spot injects markup of layout control -->
# <style>
#  /*div.wrap { */
#   /* top: 0px; */
#   /* margin-top: 0% !important;*/
#   /* }*/
#  p.destacado {
#
#   margin: 0 0 15px !important;
#
#
# }
# </style>
# <div anchor="d9757fe6-bb27-45ea-9357-823822aae8a2" class="section mobile" data-image="/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK" order="1.0" style="display:none;background-image: url('/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK')">
# <div class="wrap" style="/*margin-left:98px;margin-right:98px;*/">
# <p class="enunciado">Solicite una Tarjeta de</p>
# <p class="destacado"> Crédito Móvil en 5 minutos</p>
# <a class="btn btn-davivienda" href="https://www.daviviendamovil.com/productos/tarjeta-credito-movil?utm_source=dfp-mobile&amp;utm_medium=selfpromoted&amp;utm_campaign=davivienda-principal_slf&amp;utm_content=2021_mobban_na&amp;utm_term=na" id="btn-d9757fe6-bb27-45ea-9357-823822aae8a2" onclick="" title="Quiero saber más">
# <i class="icono ico-boton"></i>Conozca más</a>
# </div>
# </div>
# </div>
# </section> </div>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table></section>
# <footer>
# <div class="fat-footer">
# <div class="wrap">
# <a class="btn-cerrar-footer" href="#" title="Cerrar"><i class="icono-cerrar"></i></a>
# <div class="logos">
# <ul>
# <li> <a href="#" title="Emisor BVC comprometido"><img border="0" height="40" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=bvc" width="153"/></a> </li>
# <!--<li> <a href="/wps/portal/personas/nuevo/personas/iso9001" title="System Certificacion SGS" target=""><img src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=sgs" border="0" width="110" height="110"/></a> </li>-->
# <li> <a href="#" title="Fogafín"><img border="0" height="94" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=fogafin" width="102"/></a> </li>
# </ul>
# </div>
# <div class="lineas-atencion">
# <h3>Líneas de Atención</h3>
# <ul dir="ltr">
# <li>Bogota</li>
# <li>338 3838</li>
# <li>resto del país</li>
# <li>018000 123 838</li>
# <li>Celulares Movistar</li>
# <li>Desde Estados Unidos</li>
# <li>18 555 566820</li>
# <li>Desde España</li>
# <li>00 8000 3383838</li>
# </ul>
# </div>
# <div class="links-interes">
# <h3>Links de interés</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuInteres li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuInteres").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuInteres").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuInteres"><li order="7"><a class="Buzón Virtual" href="https://www.grupobolivar.com.co/buzonvirtual/faces/login.jspx?_afrLoop=284733356685949&amp;_afrWindowMode=0&amp;_adf.ctrl-state=nbphu5xk3_9">Buzón Virtual</a></li><li order="9"><a class="Glosario" href="/wps/portal/personas/nuevo/personas/glosario">Glosario</a></li><li order="4"><a class="Información para el consumidor" href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor">Información para el consumidor</a></li><li order="5"><a class="Mapa de Sitio" href="/wps/portal/personas/nuevo/personas/mapa_del_sitio">Mapa de Sitio</a></li><li order="2"><a class="Politica de cookies" href="/wps/wcm/connect/personas/003903c8-74d1-496b-9d65-e63c696f2e52/DAV+Politica+de+cookies+03+dmc-jf.pdf?MOD=AJPERES&amp;CVID=mocYnDv">Politica de cookies</a></li><li order="3"><a class="Proteccion de datos personales" href="/wps/wcm/connect/personas/b37a90f3-47a2-49a4-98e8-3fdb85e63fab/AVISO+Y+POLITICA+DE+PRIVACIDAD+DE+DATOS+26092017+F.PDF?MOD=AJPERES&amp;CVID=lY2mqrP">Proteccion de datos personales</a></li><li order="9"><a class="Trabaje con nosotros" href="https://www.trabajarendavivienda.com">Trabaje con nosotros</a></li><li order="6"><a class="Transacciones en canales" href="/wps/wcm/connect/personas/baf799eb-28a4-4f6f-9e77-a21d8a38ef8c/19Abril21_TransaccionesCanales+%281%29+-+Juanita+Barriga+Herrera+Herrera+%281%29.pdf?MOD=AJPERES&amp;CVID=nzT7z9g">Transacciones en canales</a></li><li order="8"><a class="Términos y condiciones" href="/wps/wcm/connect/personas/d1d36687-8b5a-4124-b7d0-7f614f69a3a4/REGLAMENTO+DE+USO+CANAL+www.dav.com.pdf?MOD=AJPERES&amp;CVID=meY-yU0">Términos y condiciones</a></li></ul>
# </div>
# <div class="portales-davivienda">
# <h3>Portales Davivienda</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuPortales li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuPortales").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuPortales").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuPortales"><li order="2"><a href="https://www.catalogodavipuntos.com/" title="Catálogo Davipuntos">Catálogo Davipuntos</a></li><li order="4"><a href="/wps/portal/personas/nuevo/personas/aqui_puedo/comprar_lo_que_deseo/compras_virtuales" title="Compras Virtuales">Compras Virtuales</a></li><li order="5"><a href="https://www.mundodinersclub.com/" title="Mundo Diners Club">Mundo Diners Club</a></li><li order="1"><a href="https://www.portafoliofamiliadavivienda.com/" title="Portafolio Familia">Portafolio Familia</a></li></ul>
# <ul class="redes-sociales">
# <li><h3>Redes Sociales</h3></li>
# <li><a href="https://www.facebook.com/BancoDavivienda" target="_blank" title="Link a Facebook"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=facebook"/></a></li>
# <li><a href="https://www.youtube.com/user/bancodavivienda" target="_blank" title="Link a Youtube"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=youtube"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="wrap container">
# <a class="mostrar-fat-footer" href="#" onclick="mostrarBtnCerrarFooter()"><img src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-arriba-footer.png"/></a>
# <div class="legales">
# <img alt="Vigilado, Superintendecia Financiera de Colombia" src="/PersonasDaviviendaNewTheme/resources/img/logos/vigilado.png"/>
# <p>Banco Davivienda S.A. todos los derechos reservados 2018.</p>
# </div>
# <h1>Davivienda</h1>
# </div>
# </footer>
# <!-- Contactenos -->
# <div style="display:none;">
# <div class="contenedor-ifrm" data-id="PER" style="height:100%; width:970px;">
# <span class="b-close" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <!-- Solicitar Producto -->
# <div class="padre-contenedor-solicitar">
# <div class="contenedor-solicitar">
# <span class="b-close cerrarSolicitarContenido" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <div style="display:none;">
# <div class="contenedor-ifrm-popup-seguridad" data-id="NOT" style="height:100%; width: 503px; top:15px;">
# <span class="b-close" title="Cerrar">
# <div style="cursor: pointer; position: absolute; top: 9px; right: -30px; width: 50px; height: 50px; background:red; filter: alpha(opacity=0); opacity:0; z-index: 2002;"></div>
# </span>
# <div id="ifrm-popup-seguridad">
# <!DOCTYPE html>
#
# <html>
# <head>
# <!--<link type="text/css" href="/wps/contenthandler/dav/themelist/com.davivienda.internet.personas.theme/resources/css/estilos.min.css" rel="stylesheet" />-->
# </head>
# <body>
# <style>
# 	div#ifrm-popup-seguridad{
# 	    position: relative;
# 	    z-index: 0;
# 	}
# 	body > div.contenedor-ifrm-popup-seguridad > span > div{
# 		z-index: 1
# 	}
#        	div.modal{
#        		margin: 0px;
#        		width: 580px !important;
#        		background-image: none !important;
#        		padding: 0px;
#        		border: none;
#        		text-align: center;
#        		background-color: transparent;
#        		left: -41px;
#        	}
#        	div.modal div.content-modal a img{
#        		border-radius: 10px;
#        	}
#    </style>
# <div class="modal">
# <div class="content-modal">
# <a href="#" onclick="window.top.location.href='https://seguridad.davivienda.com'">
# <img src="/wps/wcm/connect/personas/c77837a2-29e9-4126-99d9-935aad8921f0/PopUpSeguridadPersonasV2.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-c77837a2-29e9-4126-99d9-935aad8921f0-lzrGOi-" width="499"/>
# </a>
# </div>
# </div>
# </body>
# </html>
# </div>
# <!--<iframe id="ifrm-popup-seguridad" src="https://www.davivienda.com/wps/portal/personas/nuevo/personas/notificacion/pop_up_seguridad/" scrolling="no" style="border:0; height:110%; width:100%;"></iframe>-->
# </div>
# </div>
# <!--[if lt IE 9]>
#     <script src="/PersonasDaviviendaNewTheme/resources/js/selectivizr-min.js"></script>
#     <![endif]-->
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.fullPage.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.slimscroll.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.bpopup.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jssor.slider.mini.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.browser.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/hashchange.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/funciones.min.js" type="text/javascript"></script>
# <!--<script type='text/javascript' src="http://maps.googleapis.com/maps/api/js?sensor=false"></script>-->
# <!--<script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/funciones.js"></script>
#     <script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/modal.js"></script>-->
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/accordion.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.4.5.min.js"></script> -->
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.3.2.min.js"></script> -->
# <script type="text/javascript">
#       if(isMobile){
#         $("#BtnSolicitudProductos").css("display","none");
#       }
#     </script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/flickity.pkgd.min.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/iframeResizer.min.js" type="text/javascript"></script>
# </body>
# </html>
# <script id="f5_cspm">(function(){var f5_cspm={f5_p:'JDDEJBNPHKNPEFIANPNFBJKDGLJEBJMHPMDLIBFFICMENAOBAABIDAJMHFGCFNLCACPBEEMGAAEMHDMIDJIACBFHAAPKMEBMLMLOEAHHJJLGJKDHAPJKFHBCDHFJEBLI',setCharAt:function(str,index,chr){if(index>str.length-1)return str;return str.substr(0,index)+chr+str.substr(index+1);},get_byte:function(str,i){var s=(i/16)|0;i=(i&15);s=s*32;return((str.charCodeAt(i+16+s)-65)<<4)|(str.charCodeAt(i+s)-65);},set_byte:function(str,i,b){var s=(i/16)|0;i=(i&15);s=s*32;str=f5_cspm.setCharAt(str,(i+16+s),String.fromCharCode((b>>4)+65));str=f5_cspm.setCharAt(str,(i+s),String.fromCharCode((b&15)+65));return str;},set_latency:function(str,latency){latency=latency&0xffff;str=f5_cspm.set_byte(str,40,(latency>>8));str=f5_cspm.set_byte(str,41,(latency&0xff));str=f5_cspm.set_byte(str,35,2);return str;},wait_perf_data:function(){try{var wp=window.performance.timing;if(wp.loadEventEnd>0){var res=wp.loadEventEnd-wp.navigationStart;if(res<60001){var cookie_val=f5_cspm.set_latency(f5_cspm.f5_p,res);window.document.cookie='f5avr1013771131aaaaaaaaaaaaaaaa_cspm_='+encodeURIComponent(cookie_val)+';path=/';}
# return;}}
# catch(err){return;}
# setTimeout(f5_cspm.wait_perf_data,100);return;},go:function(){var chunk=window.document.cookie.split(/\s*;\s*/);for(var i=0;i<chunk.length;++i){var pair=chunk[i].split(/\s*=\s*/);if(pair[0]=='f5_cspm'&&pair[1]=='1234')
# {var d=new Date();d.setTime(d.getTime()-1000);window.document.cookie='f5_cspm=;expires='+d.toUTCString()+';path=/;';setTimeout(f5_cspm.wait_perf_data,100);}}}}
# f5_cspm.go();}());</script>>

# %% [markdown]
# Nada parecido a lo que queremos encontrar...
#
# Intentemos otro link de la misma página:

# %%
url = 'https://www.davivienda.com/wps/portal/personas/nuevo#iframe'
webpage = urlopen(url) 
soup = BeautifulSoup(webpage, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><link href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" rel="icon" type="image/x-icon"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/normalize.css" rel="stylesheet"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/estilos-wps9.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/s-pagos-pse.css" rel="stylesheet" type="text/css"/>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/modernizr.js" type="text/javascript"></script>
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - INICIO -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/easyXDM.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/openIframe.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/openIframe.js"></script>-->
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - FIN -->
# <!-- Can run Adserver validation -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/ads.min.js"></script>
# <!-- End run Adserver validation -->
# <script type="text/javascript">
#
#     var divAdserverId = 'div-gpt-ad-1499960009335-0';
#       var getGpt = false;
#       var isMobile = false; //initiate as false
#       // device detection
#       if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|ipad|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(navigator.userAgent) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(navigator.userAgent.substr(0,4)))
#         isMobile = true;
#
#       function iframeHeight(height) {
#         $('#ifrm-contenedor').height(height + 100);
#       }
#       function mostrarBtnCerrarFooter () {
#         $('a.btn-cerrar-footer').css('top','');
#         $('a.btn-cerrar-footer').css('top','-30px;');
#       }
#       $(document).on("ready",function(){
#         $("#row_8").css("display","none");
#       });
#     var gtmFn = function () {
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGtm = $.ajax({
#         type:'GET',
#         url:'https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5',
#         data:null,
#         timeout: 1000,
#         success:function(){
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-WVX9Z5');
#         adserverFn();
#         },
#       error: function(xmlhttprequest, textstatus, message) {
#         if(textstatus==="timeout") {
#           console.error("cannot load GTM libs");
#           element.css('background-image', 'url(' + image + ')');
#         } else {
#           console.error("something happened and cannot load GTM libs");
#         }
#       },
#         dataType:'script'
#       });
#
#     };
#     var adserverFn = function(){
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGpt = $.ajax({
#       type:'GET',
#         url:'https://www.googletagservices.com/tag/js/gpt.js',
#         data:null,
#           timeout: 1000,
#         success:function(){
#          getGpt = true;
#          console.debug("success callback exec");
#         },
#         error: function(xmlhttprequest, textstatus, message) {
#           if(textstatus==="timeout") {
#               console.error("cannot load Adserver libs");
#         console.log(xmlhttprequest);
#         console.log(message);
#               element.css('background-image', 'url(' + image + ')');
#           } else {
#               console.error("something happened and cannot load Adserver libs");
#           }
#         },
#         dataType:'script'
#       });
#       var googletag = googletag || {};
#     var matriz =[[1366,768 ],[1920,1080],[1600,900 ],[1440,900 ],[1280,800 ],[1280,1024],[1360,768 ],[1024,768 ],[1280,720 ],[1536,864 ],[1680,1050],[1093,615 ],[2560,1440],[1280,768 ],[1024,600 ],[360,640  ],[1920,1200],[1093,614 ],[1152,720 ],[1152,864 ],[1301,731 ],[1024,820 ],[1438,808 ],[1280,960 ],[1518,853 ],[1242,698 ],[1344,840 ],[1607,904 ]];
#     var idx = -1;
#     var ancho=0;
#     var alto=0;
#     for (i = 0; i < matriz.length; i++) {
#       ancho=parseInt(matriz[i][0]);
#       alto = parseInt(matriz[i][1]);
#       if (ancho ==parseInt(screen.width) && alto ==parseInt(screen.height)){
#         idx= 0;
#          break;
#       }
#     }
#       googletag.cmd = googletag.cmd || [];
#
#       if( window.canRunAds === true ){
#     if (idx !=  -1){
#         ajaxGpt.then(function(){
#         console.debug("then ajaxGpt callback exec");
#             banner.empty();
#         banner.append("<div id='" + divAdserverId + "' ></div>");
#       var elementAds = $( '#'+divAdserverId );
#       elementAds.find('div').css("height", window.innerHeight);
#       elementAds.find('div').css("width", window.innerWidth);
#       elementAds.find('iframe').css("height", window.innerHeight);
#       elementAds.find('iframe').css("width", window.innerWidth);
#         });
#       }else{
#         element.css('background-image', 'url(' + image + ')');
#       }
#     }
#     else{
#         element.css('background-image', 'url(' + image + ')');
#     }
#     };
#    </script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   </script>
# <script>
#     googletag.cmd.push(function() {
#
#
#       /* DEFINE SLOT */
#       googletag.defineSlot('/236880650/Home_Daviviendacombanner', [screen.width,screen.height], divAdserverId).addService(googletag.pubads()).
#       addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.enableServices();
#       });
#       googletag.cmd.push(function() { googletag.display(divAdserverId);});
#
#
#   </script>
# </head>
# <body onload="gtmFn()">
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="auto !important" src="https://www.googletagmanager.com/ns.html?id=GTM-WVX9Z5" style="display:none;visibility:hidden" width="100%"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- JPG - LOADING SCREEN - INICIO -->
# <div class="loadingScreen">
# <img src="/PersonasDaviviendaNewTheme/resources/img/iconos/loadingScreenIcon.gif"/>
# </div>
# <!-- JPG - LOADING SCREEN - FIN -->
# <header>
# <div class="login">
# <div class="wrap">
# <div class="form" style="width:100%;padding:0px;">
# <div id="divIFrame" style="border:none;overflow:hidden;height: 310px; width: 100%;display:block;">
# </div>
# <a class="btn-cerrar" href="#" id="personas-cerrar-ingresar" title="Cerrar"><i class="icono-cerrar"></i></a>
# </div>
# </div>
# </div>
# <div class="cabecera">
# <div class="wrap container">
# <div class="four columns">
# <a class="current" href="/wps/portal/personas/nuevo" id="personas-volver-head" title="Volver a Home personas"><h1>Davivienda</h1></a>
# </div>
# <div class="three columns">
# <div class="tipo-acceso">
# <nav class="acceso">
# <ul>
# <li>
# <a class="activo" href="#" title="Personas">
# <i class="icono personas"></i>Personas</a><img class="img_indicador" src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-indicador.png"/>
# </li>
# <li>
# <a href="/wps/portal/empresas/nuevo" id="empresas-volver-head" title="Empresas">
# <i class="icono empresas"></i>Empresas
#                     </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <!--tipo-acceso-->
# <div class="three columns column-info-corporativa">
# <!-- Escritorio -->
# <div class="info-corporativa info-corporativa-desktop">
# <ul>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li>
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# <!-- Móvil -->
# <div class="info-corporativa info-corporativa-mobile">
# <ul class="gallery js-flickity" data-flickity-options='{ "wrapAround": false }'>
# <li class="gallery-cell">
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li class="gallery-cell">
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li class="gallery-cell">
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="two columns column-despliegue-login">
# <div class="despliegue-login">
# <a class="mostrar-login" href="#" id="personas-ingresar" onclick="openIframe('https://transacciones.davivienda.com/transaccional/personas/nuevo/login.jsf');abrirPopUpSeguridad(); event.preventDefault();" title="Ingresar"><i class="icono login"></i>Ingreso
#                 <br/>Clientes
#               </a>
# </div>
# </div>
# <!--despliegue-login-->
# </div>
# <div class="aqui-puedo">
# <div class="wrap container">
# <a class="desplegar-aqui-puedo" href="#" id="desplegable-aqui-puedo" title="Aquí puedo">
# </a>
# <div class="buscador">
# <!-- Mostrar Enlace en lugar de Input -->
# <a href="/wps/portal/personas/nuevo/personas/Atencionenlinea" id="BtnAtencionenlinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_atencion_linea_nuevo" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Atención en línea</span>
# </a>
# <a href="/wps/portal/personas/nuevo/personas/aqui_puedo/pagar_facilmente/pse/" id="BtnPagosEnLinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_pagos_en_linea_PSE" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Pagos en línea y PSE</span>
# </a>
# </div>
# </div>
# <nav class="aqui-puedo">
# <!-- <a rel="dynamic-content" href="dyn-cs:id:ThemePersonas_tabNav"></a> -->
# <!--SESSION COOKIE-->
# <div class="wrap menu" style="max-width:1170px; width: 100%;">
# <!--menú normal -->
# <div id="iterator_menu"></div>
# <!--menú responsive-->
# <div class="accordion" id="responsive_menu">
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# 																				Construir mi futuro
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																							Vivienda
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																							Vehículo
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																							Inversiones
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																							Pensión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																							Educación
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																							Ahorros
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1065">
# 																				Manejar mi dinero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1065">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																							Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																							Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																							Planeación de Impuestos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																							Tarjetas Débito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																							Giros Directos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																							Giros internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# 																				Alcanzar lo que quiero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																							Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																							Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																							Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																							Crédito Fractionals
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																							Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# 																				Comprar lo que deseo
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																							Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																							Mundo Diners
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																							Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																							Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																							Compras virtuales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# 																				Respaldar a mi familia
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																							Portafolio Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																							Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																							Cuenta Niños
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																							Tarjeta Mujer
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																							Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# 																				Administrar mis inversiones
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																							Davivienda Colombia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																							Davivienda Panamá
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																							Davivienda Miami
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																							Davivienda Corredores
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																							Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GE7">
# 																				Proteger mi patrimonio
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GE7">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																							Seguros para Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																							Seguros para Bienes
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																							Seguros para Casa
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																							Seguros para Carro
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																							Asistencias
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G96">
# 																				Pagar fácilmente
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G96">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																							Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																							Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																							Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																							Transferencias Automaticas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS4" id="menu-personas-comprar-con-codigo-qr" onclick="var nm='Comprar con código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Comprar con código QR">
# 																							Comprar con código QR
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS5" id="menu-personas-vender-con-codigo-qr" onclick="var nm='Vender con Código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vender con Código QR">
# 																							Vender con Código QR
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div id="cnt" style="display:none;">
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono casa"></i>
# 																					Construir mi futuro
# 																				</li>
# <li style="height: auto;">Paso a paso le ayudamos en el Crecimiento de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																						Vivienda
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																						Vehículo
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																						Inversiones
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																						Pensión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																						Educación
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																						Ahorros
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono dinero"></i>
# 																					Manejar mi dinero
# 																				</li>
# <li style="height: auto;">Desde una cuenta de ahorros hasta un portafolio completo de servicios.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																						Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																						Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																						Planeación de Impuestos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																						Tarjetas Débito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																						Giros Directos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																						Giros internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono compra"></i>
# 																					Alcanzar lo que quiero
# 																				</li>
# <li style="height: auto;">Crédito de consumo que se adapta a sus necesidades.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																						Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																						Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																						Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																						Crédito Fractionals
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																						Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono tarjeta"></i>
# 																					Comprar lo que deseo
# 																				</li>
# <li style="height: auto;">Las Tarjetas de Crédito Davivienda le sirven para todo incluso para comprar.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																						Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																						Mundo Diners
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																						Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																						Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																						Compras virtuales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono familia"></i>
# 																					Respaldar a mi familia
# 																				</li>
# <li style="height: auto;">Productos pensandos para apoyar a los que más quiere.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																						Portafolio Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																						Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																						Cuenta Niños
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																						Tarjeta Mujer
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																						Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono grafico"></i>
# 																					Administrar mis inversiones
# 																				</li>
# <li style="height: auto;">Banca Patrimonial, una asesoría profesional en el manejo de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																						Davivienda Colombia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																						Davivienda Panamá
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																						Davivienda Miami
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																						Davivienda Corredores
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																						Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono proteger"></i>
# 																					Proteger mi patrimonio
# 																				</li>
# <li style="height: auto;">Aquí le ayudamos a asegurar todo lo que ha construido.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																						Seguros para Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																						Seguros para Bienes
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																						Seguros para Casa
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																						Seguros para Carro
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																						Asistencias
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono pagar"></i>
# 																					Pagar fácilmente
# 																				</li>
# <li style="height: auto;">Realice de forma sencilla el pago de sus obligaciones.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																						Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																						Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																						Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																						Transferencias Automaticas
# 																						</a>
# </li>
# <li class="list-cnt">
# ...
# <!-- LINKS divItemInferiorM RESPALDO -->
# <div class="divItemInferiorM-respaldo" style="display:none;">
# <ul class="opciones-usuario">
# <li><a href="https://daviplata.com" title="Inicio"><i class="icon-ap ico-conocer"></i>Conocer <span>DaviPlata</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/Educacion_Financiera/" title="Inicio"><i class="icon-ap ico-aprender"></i>Educación  <span>Financiera</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/asesorarme_si_vivo_o_viajo_al_exterior/" title="Inicio"><i class="icon-ap ico-asesorame"></i>Asesorarme <span>si vivo o viajo al exterior</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor" title="Inicio"><i class="icon-ap ico-aprender"></i>Defensor del  <span>consumidor financiero</span></a></li>
# </ul>
# </div>
# <script type="text/javascript">
#     $(function() {
#         var opcionesUsuario = $('#divItemInferiorM').children('ul');
#         if (typeof opcionesUsuario === "undefined") {
#         	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#         } else {
#           	if ( opcionesUsuario.length <= 0 ) {
#             	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#           	}
#         }
#     });
# </script>
# <script type="text/javascript">
#
# function abrirPopUpSeguridad(){
#
#     var IE = 9
#     var MZ = 14
#     var GC = 41
#
# 	var browser = get_browser_info();
#
# 	/*Internet Explorer*/
# 	if (navigator.userAgent.indexOf('MSIE') !=-1 && browser.version >= IE) {
# 	    abrirPopUp();
# 	}
# 	/*Mozilla Firefox*/
# 	else if (navigator.userAgent.indexOf('Firefox') !=-1 && browser.version >= MZ) {
# 		abrirPopUp();
# 	}
# 	/*Google Chrome*/
# 	else if (navigator.userAgent.indexOf('Chrome') !=-1 && browser.version >= GC) {
# 		abrirPopUp();
# 	}
#
# };
#
# function get_browser_info(){
#     var ua=navigator.userAgent,tem,M=ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#     if(/trident/i.test(M[1])){
#         tem=/\brv[ :]+(\d+)/g.exec(ua) || [];
#         return {name:'IE',version:(tem[1]||'')};
#         }
#     if(M[1]==='Chrome'){
#         tem=ua.match(/\bOPR\/(\d+)/);
#         if(tem!=null)   {return {name:'Opera', version:tem[1]};}
#         }
#     M=M[2]? [M[1], M[2]]: [navigator.appName, navigator.appVersion, '-?'];
#     if((tem=ua.match(/version\/(\d+)/i))!=null) {M.splice(1,1,tem[1]);}
#     return {
#       name: M[0],
#       version: M[1]
#     };
# }
#
# var notificacion = false;
#
# function abrirPopUp(){
#     if (!isMobile) {
#     	/*var scroll = 0;
#     	$('div.contenedor-ifrm-popup-seguridad').bPopup({
#     		position: ['auto', scroll ],
#     		positionStyle: 'fixed'
# 	});*/
# }}
#
# </script>
# </link></div>
# </section> </div>
# </td>
# </tr>
# <tr>
# <td style="width:100%;" valign="top">
# <div class="component-control id-Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"><span id="Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"></span><section class="ibmPortalControl wpthemeNoSkin a11yRegionTarget" role="region">
# <!-- marks the node the analytics tags for this portlet will be placed in -->
# <div class="asa.portlet" id="asa.portlet.Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1" style="display:none;">
# <span class="asa.portlet.id">Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1</span>
# </div>
# <!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# <div style="position:relative; z-index: 1;">
# <div class="analytics.overlay"></div>
# </div>
# <!-- Hide the text of the title, but still provide the lm-dynamic-title container for accessing the dynamic title -->
# <span class="wpthemeAccess">
# <span class="lm-dynamic-title asa.portlet.title a11yRegionLabel"><span dir="ltr" lang="en">Web Content Viewer</span></span>
# </span>
# <div class="wpthemeOverflowAuto"> <!-- lm:control dynamic spot injects markup of layout control -->
# <style>
#  /*div.wrap { */
#   /* top: 0px; */
#   /* margin-top: 0% !important;*/
#   /* }*/
#  p.destacado {
#
#   margin: 0 0 15px !important;
#
#
# }
# </style>
# <div anchor="d9757fe6-bb27-45ea-9357-823822aae8a2" class="section mobile" data-image="/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK" order="1.0" style="display:none;background-image: url('/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK')">
# <div class="wrap" style="/*margin-left:98px;margin-right:98px;*/">
# <p class="enunciado">Solicite una Tarjeta de</p>
# <p class="destacado"> Crédito Móvil en 5 minutos</p>
# <a class="btn btn-davivienda" href="https://www.daviviendamovil.com/productos/tarjeta-credito-movil?utm_source=dfp-mobile&amp;utm_medium=selfpromoted&amp;utm_campaign=davivienda-principal_slf&amp;utm_content=2021_mobban_na&amp;utm_term=na" id="btn-d9757fe6-bb27-45ea-9357-823822aae8a2" onclick="" title="Quiero saber más">
# <i class="icono ico-boton"></i>Conozca más</a>
# </div>
# </div>
# </div>
# </section> </div>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table></section>
# <footer>
# <div class="fat-footer">
# <div class="wrap">
# <a class="btn-cerrar-footer" href="#" title="Cerrar"><i class="icono-cerrar"></i></a>
# <div class="logos">
# <ul>
# <li> <a href="#" title="Emisor BVC comprometido"><img border="0" height="40" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=bvc" width="153"/></a> </li>
# <!--<li> <a href="/wps/portal/personas/nuevo/personas/iso9001" title="System Certificacion SGS" target=""><img src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=sgs" border="0" width="110" height="110"/></a> </li>-->
# <li> <a href="#" title="Fogafín"><img border="0" height="94" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=fogafin" width="102"/></a> </li>
# </ul>
# </div>
# <div class="lineas-atencion">
# <h3>Líneas de Atención</h3>
# <ul dir="ltr">
# <li>Bogota</li>
# <li>338 3838</li>
# <li>resto del país</li>
# <li>018000 123 838</li>
# <li>Celulares Movistar</li>
# <li>Desde Estados Unidos</li>
# <li>18 555 566820</li>
# <li>Desde España</li>
# <li>00 8000 3383838</li>
# </ul>
# </div>
# <div class="links-interes">
# <h3>Links de interés</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuInteres li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuInteres").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuInteres").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuInteres"><li order="7"><a class="Buzón Virtual" href="https://www.grupobolivar.com.co/buzonvirtual/faces/login.jspx?_afrLoop=284733356685949&amp;_afrWindowMode=0&amp;_adf.ctrl-state=nbphu5xk3_9">Buzón Virtual</a></li><li order="9"><a class="Glosario" href="/wps/portal/personas/nuevo/personas/glosario">Glosario</a></li><li order="4"><a class="Información para el consumidor" href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor">Información para el consumidor</a></li><li order="5"><a class="Mapa de Sitio" href="/wps/portal/personas/nuevo/personas/mapa_del_sitio">Mapa de Sitio</a></li><li order="2"><a class="Politica de cookies" href="/wps/wcm/connect/personas/003903c8-74d1-496b-9d65-e63c696f2e52/DAV+Politica+de+cookies+03+dmc-jf.pdf?MOD=AJPERES&amp;CVID=mocYnDv">Politica de cookies</a></li><li order="3"><a class="Proteccion de datos personales" href="/wps/wcm/connect/personas/b37a90f3-47a2-49a4-98e8-3fdb85e63fab/AVISO+Y+POLITICA+DE+PRIVACIDAD+DE+DATOS+26092017+F.PDF?MOD=AJPERES&amp;CVID=lY2mqrP">Proteccion de datos personales</a></li><li order="9"><a class="Trabaje con nosotros" href="https://www.trabajarendavivienda.com">Trabaje con nosotros</a></li><li order="6"><a class="Transacciones en canales" href="/wps/wcm/connect/personas/baf799eb-28a4-4f6f-9e77-a21d8a38ef8c/19Abril21_TransaccionesCanales+%281%29+-+Juanita+Barriga+Herrera+Herrera+%281%29.pdf?MOD=AJPERES&amp;CVID=nzT7z9g">Transacciones en canales</a></li><li order="8"><a class="Términos y condiciones" href="/wps/wcm/connect/personas/d1d36687-8b5a-4124-b7d0-7f614f69a3a4/REGLAMENTO+DE+USO+CANAL+www.dav.com.pdf?MOD=AJPERES&amp;CVID=meY-yU0">Términos y condiciones</a></li></ul>
# </div>
# <div class="portales-davivienda">
# <h3>Portales Davivienda</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuPortales li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuPortales").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuPortales").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuPortales"><li order="2"><a href="https://www.catalogodavipuntos.com/" title="Catálogo Davipuntos">Catálogo Davipuntos</a></li><li order="4"><a href="/wps/portal/personas/nuevo/personas/aqui_puedo/comprar_lo_que_deseo/compras_virtuales" title="Compras Virtuales">Compras Virtuales</a></li><li order="5"><a href="https://www.mundodinersclub.com/" title="Mundo Diners Club">Mundo Diners Club</a></li><li order="1"><a href="https://www.portafoliofamiliadavivienda.com/" title="Portafolio Familia">Portafolio Familia</a></li></ul>
# <ul class="redes-sociales">
# <li><h3>Redes Sociales</h3></li>
# <li><a href="https://www.facebook.com/BancoDavivienda" target="_blank" title="Link a Facebook"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=facebook"/></a></li>
# <li><a href="https://www.youtube.com/user/bancodavivienda" target="_blank" title="Link a Youtube"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=youtube"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="wrap container">
# <a class="mostrar-fat-footer" href="#" onclick="mostrarBtnCerrarFooter()"><img src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-arriba-footer.png"/></a>
# <div class="legales">
# <img alt="Vigilado, Superintendecia Financiera de Colombia" src="/PersonasDaviviendaNewTheme/resources/img/logos/vigilado.png"/>
# <p>Banco Davivienda S.A. todos los derechos reservados 2018.</p>
# </div>
# <h1>Davivienda</h1>
# </div>
# </footer>
# <!-- Contactenos -->
# <div style="display:none;">
# <div class="contenedor-ifrm" data-id="PER" style="height:100%; width:970px;">
# <span class="b-close" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <!-- Solicitar Producto -->
# <div class="padre-contenedor-solicitar">
# <div class="contenedor-solicitar">
# <span class="b-close cerrarSolicitarContenido" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <div style="display:none;">
# <div class="contenedor-ifrm-popup-seguridad" data-id="NOT" style="height:100%; width: 503px; top:15px;">
# <span class="b-close" title="Cerrar">
# <div style="cursor: pointer; position: absolute; top: 9px; right: -30px; width: 50px; height: 50px; background:red; filter: alpha(opacity=0); opacity:0; z-index: 2002;"></div>
# </span>
# <div id="ifrm-popup-seguridad">
# <!DOCTYPE html>
#
# <html>
# <head>
# <!--<link type="text/css" href="/wps/contenthandler/dav/themelist/com.davivienda.internet.personas.theme/resources/css/estilos.min.css" rel="stylesheet" />-->
# </head>
# <body>
# <style>
# 	div#ifrm-popup-seguridad{
# 	    position: relative;
# 	    z-index: 0;
# 	}
# 	body > div.contenedor-ifrm-popup-seguridad > span > div{
# 		z-index: 1
# 	}
#        	div.modal{
#        		margin: 0px;
#        		width: 580px !important;
#        		background-image: none !important;
#        		padding: 0px;
#        		border: none;
#        		text-align: center;
#        		background-color: transparent;
#        		left: -41px;
#        	}
#        	div.modal div.content-modal a img{
#        		border-radius: 10px;
#        	}
#    </style>
# <div class="modal">
# <div class="content-modal">
# <a href="#" onclick="window.top.location.href='https://seguridad.davivienda.com'">
# <img src="/wps/wcm/connect/personas/c77837a2-29e9-4126-99d9-935aad8921f0/PopUpSeguridadPersonasV2.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-c77837a2-29e9-4126-99d9-935aad8921f0-lzrGOi-" width="499"/>
# </a>
# </div>
# </div>
# </body>
# </html>
# </div>
# <!--<iframe id="ifrm-popup-seguridad" src="https://www.davivienda.com/wps/portal/personas/nuevo/personas/notificacion/pop_up_seguridad/" scrolling="no" style="border:0; height:110%; width:100%;"></iframe>-->
# </div>
# </div>
# <!--[if lt IE 9]>
#     <script src="/PersonasDaviviendaNewTheme/resources/js/selectivizr-min.js"></script>
#     <![endif]-->
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.fullPage.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.slimscroll.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.bpopup.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jssor.slider.mini.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.browser.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/hashchange.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/funciones.min.js" type="text/javascript"></script>
# <!--<script type='text/javascript' src="http://maps.googleapis.com/maps/api/js?sensor=false"></script>-->
# <!--<script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/funciones.js"></script>
#     <script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/modal.js"></script>-->
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/accordion.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.4.5.min.js"></script> -->
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.3.2.min.js"></script> -->
# <script type="text/javascript">
#       if(isMobile){
#         $("#BtnSolicitudProductos").css("display","none");
#       }
#     </script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/flickity.pkgd.min.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/iframeResizer.min.js" type="text/javascript"></script>
# </body>
# </html>
# <script id="f5_cspm">(function(){var f5_cspm={f5_p:'HGANNFEJOMJNJOLKIPDGJFGHJJGFDKKFOOJLEJDDCHICAOPLJKOGHABDDCBMPLNIAPDBDOKAAAMMKIHHMADAGGABAAHPOKFHOHLDEMNKLOMMMLHICBCEOGKABMNAILOO',setCharAt:function(str,index,chr){if(index>str.length-1)return str;return str.substr(0,index)+chr+str.substr(index+1);},get_byte:function(str,i){var s=(i/16)|0;i=(i&15);s=s*32;return((str.charCodeAt(i+16+s)-65)<<4)|(str.charCodeAt(i+s)-65);},set_byte:function(str,i,b){var s=(i/16)|0;i=(i&15);s=s*32;str=f5_cspm.setCharAt(str,(i+16+s),String.fromCharCode((b>>4)+65));str=f5_cspm.setCharAt(str,(i+s),String.fromCharCode((b&15)+65));return str;},set_latency:function(str,latency){latency=latency&0xffff;str=f5_cspm.set_byte(str,40,(latency>>8));str=f5_cspm.set_byte(str,41,(latency&0xff));str=f5_cspm.set_byte(str,35,2);return str;},wait_perf_data:function(){try{var wp=window.performance.timing;if(wp.loadEventEnd>0){var res=wp.loadEventEnd-wp.navigationStart;if(res<60001){var cookie_val=f5_cspm.set_latency(f5_cspm.f5_p,res);window.document.cookie='f5avr1013771131aaaaaaaaaaaaaaaa_cspm_='+encodeURIComponent(cookie_val)+';path=/';}
# return;}}
# catch(err){return;}
# setTimeout(f5_cspm.wait_perf_data,100);return;},go:function(){var chunk=window.document.cookie.split(/\s*;\s*/);for(var i=0;i<chunk.length;++i){var pair=chunk[i].split(/\s*=\s*/);if(pair[0]=='f5_cspm'&&pair[1]=='1234')
# {var d=new Date();d.setTime(d.getTime()-1000);window.document.cookie='f5_cspm=;expires='+d.toUTCString()+';path=/;';setTimeout(f5_cspm.wait_perf_data,100);}}}}
# f5_cspm.go();}());</script>>

# %%
import time

url = 'https://www.davivienda.com/wps/portal/personas/nuevo#iframe'

browser1 = webdriver.PhantomJS(executable_path=r"C:\phantomjs\bin\phantomjs.exe")
  
browser1.get(url)
html1 = browser1.page_source

time.sleep(5)

# %%
html1
# Out:
# '<!DOCTYPE html><html lang="en" class=" " style="overflow: hidden; height: 100%;"><head>\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\n    <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script type="text/javascript" async="" src="//img03.en25.com/i/elqCfg.min.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-955ZS6ZPLE&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" src="/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js" data-dtconfig="app=6e3a0d00a63302d9|rcdec=1209600000|featureHash=ICA27SVfgjqruvx|vcv=2|rdnt=1|uxrgce=1|srcss=1|bp=2|srmcrv=10|cuc=vrbxqx1s|mel=100000|dpvc=1|ssv=4|lastModification=1619184233658|dtVersion=10213210407103252|srmcrl=1|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js|reportUrl=/wps/rb_esd62814|rid=RID_-1900635789|rpid=-983866885|domain=davivienda.com"></script><script type="text/javascript" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608"></script><script type="text/javascript" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469"></script><script type="text/javascript" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794"></script><link rel="icon" href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" type="image/x-icon">\n    <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" type="text/css" rel="stylesheet">\n    \n    <link rel="stylesheet" href="/PersonasDaviviendaNewTheme/resources/css/normalize.css">\n    \n    <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" type="text/css" rel="stylesheet">\n    <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" type="text/css" rel="stylesheet">\n    <link rel="stylesheet" type="text/css" href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css">\n  \n    <link rel="stylesheet" type="text/css" href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css">\n    <link rel="stylesheet" type="text/css" href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resource ...

# %%
browser2 = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
time.sleep(5)
browser2.get(url)
html2 = browser2.page_source
time.sleep(5)
browser2.quit()
html2
# Out:
# '<html lang="en" class=" " style="overflow: hidden; height: 100%;"><head><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5&amp;_=1619271306014"></script>\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\n    <script type="text/javascript" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608"></script><script type="text/javascript" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469"></script><script type="text/javascript" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794"></script><link rel="icon" href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" type="image/x-icon">\n    <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" type="text/css" rel="stylesheet">\n    \n    <link rel="stylesheet" href="/PersonasDaviviendaNewTheme/resources/css/normalize.css">\n    \n    <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" type="text/css" rel="stylesheet">\n    <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" type="text/css" rel="stylesheet">\n    <link rel="stylesheet" type="text/css" href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css">\n  \n    <link rel="stylesheet" type="text/css" href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css">\n    <link rel="stylesheet" type="text/css" href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/estilos-wps9.css">\n    <link rel="stylesheet" type="text/css" href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/s-pagos-pse.css">\n\n    <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.min.js"></script>\n    <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery-ui.min.js"></script>\n    <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/modernizr.js"></script>\n\n    <!-- IBM - MENSAJERÍA CROSSDOMAIN - INICIO -->\n    <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/easyXDM.min.js"></script>\n    <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/openIframe.js"></script>\n    <!--<script type="text/javascript" src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/openIframe.js"></script>-->\n    <!-- IBM - MENSAJE ...

# %% [markdown]
# Acabamos de abrir el url con el buscador **Phantom** y **Chrome** por medio de Python

# %%
# Esta línea permite ejecutar el Javascript

html = browser1.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
    
soup = BeautifulSoup(html, "html.parser")

# %%
soup
# Out:
# <head>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="//img03.en25.com/i/elqCfg.min.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-955ZS6ZPLE&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script data-dtconfig="app=6e3a0d00a63302d9|rcdec=1209600000|featureHash=ICA27SVfgjqruvx|vcv=2|rdnt=1|uxrgce=1|srcss=1|bp=2|srmcrv=10|cuc=vrbxqx1s|mel=100000|dpvc=1|ssv=4|lastModification=1619184233658|dtVersion=10213210407103252|srmcrl=1|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js|reportUrl=/wps/rb_esd62814|rid=RID_-1900635789|rpid=1883729298|domain=davivienda.com" src="/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><link href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" rel="icon" type="image/x-icon"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/normalize.css" rel="stylesheet"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/estilos-wps9.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/s-pagos-pse.css" rel="stylesheet" type="text/css"/>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/modernizr.js" type="text/javascript"></script>
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - INICIO -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/easyXDM.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/openIframe.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/openIframe.js"></script>-->
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - FIN -->
# <!-- Can run Adserver validation -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/ads.min.js"></script>
# <!-- End run Adserver validation -->
# <script type="text/javascript">
#
#     var divAdserverId = 'div-gpt-ad-1499960009335-0';
#       var getGpt = false;
#       var isMobile = false; //initiate as false
#       // device detection
#       if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|ipad|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(navigator.userAgent) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(navigator.userAgent.substr(0,4)))
#         isMobile = true;
#
#       function iframeHeight(height) {
#         $('#ifrm-contenedor').height(height + 100);
#       }
#       function mostrarBtnCerrarFooter () {
#         $('a.btn-cerrar-footer').css('top','');
#         $('a.btn-cerrar-footer').css('top','-30px;');
#       }
#       $(document).on("ready",function(){
#         $("#row_8").css("display","none");
#       });
#     var gtmFn = function () {
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGtm = $.ajax({
#         type:'GET',
#         url:'https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5',
#         data:null,
#         timeout: 1000,
#         success:function(){
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-WVX9Z5');
#         adserverFn();
#         },
#       error: function(xmlhttprequest, textstatus, message) {
#         if(textstatus==="timeout") {
#           console.error("cannot load GTM libs");
#           element.css('background-image', 'url(' + image + ')');
#         } else {
#           console.error("something happened and cannot load GTM libs");
#         }
#       },
#         dataType:'script'
#       });
#
#     };
#     var adserverFn = function(){
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGpt = $.ajax({
#       type:'GET',
#         url:'https://www.googletagservices.com/tag/js/gpt.js',
#         data:null,
#           timeout: 1000,
#         success:function(){
#          getGpt = true;
#          console.debug("success callback exec");
#         },
#         error: function(xmlhttprequest, textstatus, message) {
#           if(textstatus==="timeout") {
#               console.error("cannot load Adserver libs");
#         console.log(xmlhttprequest);
#         console.log(message);
#               element.css('background-image', 'url(' + image + ')');
#           } else {
#               console.error("something happened and cannot load Adserver libs");
#           }
#         },
#         dataType:'script'
#       });
#       var googletag = googletag || {};
#     var matriz =[[1366,768 ],[1920,1080],[1600,900 ],[1440,900 ],[1280,800 ],[1280,1024],[1360,768 ],[1024,768 ],[1280,720 ],[1536,864 ],[1680,1050],[1093,615 ],[2560,1440],[1280,768 ],[1024,600 ],[360,640  ],[1920,1200],[1093,614 ],[1152,720 ],[1152,864 ],[1301,731 ],[1024,820 ],[1438,808 ],[1280,960 ],[1518,853 ],[1242,698 ],[1344,840 ],[1607,904 ]];
#     var idx = -1;
#     var ancho=0;
#     var alto=0;
#     for (i = 0; i < matriz.length; i++) {
#       ancho=parseInt(matriz[i][0]);
#       alto = parseInt(matriz[i][1]);
#       if (ancho ==parseInt(screen.width) && alto ==parseInt(screen.height)){
#         idx= 0;
#          break;
#       }
#     }
#       googletag.cmd = googletag.cmd || [];
#
#       if( window.canRunAds === true ){
#     if (idx !=  -1){
#         ajaxGpt.then(function(){
#         console.debug("then ajaxGpt callback exec");
#             banner.empty();
#         banner.append("<div id='" + divAdserverId + "' ></div>");
#       var elementAds = $( '#'+divAdserverId );
#       elementAds.find('div').css("height", window.innerHeight);
#       elementAds.find('div').css("width", window.innerWidth);
#       elementAds.find('iframe').css("height", window.innerHeight);
#       elementAds.find('iframe').css("width", window.innerWidth);
#         });
#       }else{
#         element.css('background-image', 'url(' + image + ')');
#       }
#     }
#     else{
#         element.css('background-image', 'url(' + image + ')');
#     }
#     };
#    </script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   </script>
# <script>
#     googletag.cmd.push(function() {
#
#
#       /* DEFINE SLOT */
#       googletag.defineSlot('/236880650/Home_Daviviendacombanner', [screen.width,screen.height], divAdserverId).addService(googletag.pubads()).
#       addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.enableServices();
#       });
#       googletag.cmd.push(function() { googletag.display(divAdserverId);});
#
#
#   </script>
# <meta content="A+b/H0b8RPXNaJgaNFpO0YOFuGK6myDQXlwnJB3SwzvNMfcndat4DZYMrP4ClJIzYWo3/yP2S+8FTZ/lpqbPAAEAAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MjYyMjA3OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="A7+rMYR5onPnACrz+niKSeFdH3xw1IyHo2AZSHmxrofRk9w4HcQPMYcpBUKu6OQ6zsdxf4m/vqa6tG6Na4OLpAQAAAB4eyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiQ29udmVyc2lvbk1lYXN1cmVtZW50IiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1RoaXJkUGFydHkiOnRydWV9" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021042001.js"></script><link href="https://adservice.google.com/adsid/integrator.js?domain=www.davivienda.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.davivienda.com" type="text/javascript"></script></head>
# <body onload="gtmFn()" style="overflow: hidden; height: 100%;">
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>&lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WVX9Z5" height="auto !important" width="100%" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- JPG - LOADING SCREEN - INICIO -->
# <div class="loadingScreen">
# <img src="/PersonasDaviviendaNewTheme/resources/img/iconos/loadingScreenIcon.gif"/>
# </div>
# <!-- JPG - LOADING SCREEN - FIN -->
# <header>
# <div class="login">
# <div class="wrap">
# <div class="form" style="width:100%;padding:0px;">
# <div id="divIFrame" style="border:none;overflow:hidden;height: 310px; width: 100%;display:block;">
# </div>
# <a class="btn-cerrar" href="#" id="personas-cerrar-ingresar" title="Cerrar"><i class="icono-cerrar"></i></a>
# </div>
# </div>
# </div>
# <div class="cabecera">
# <div class="wrap container">
# <div class="four columns">
# <a class="current" href="/wps/portal/personas/nuevo" id="personas-volver-head" title="Volver a Home personas"><h1>Davivienda</h1></a>
# </div>
# <div class="three columns">
# <div class="tipo-acceso">
# <nav class="acceso">
# <ul>
# <li>
# <a class="activo" href="#" title="Personas">
# <i class="icono personas"></i>Personas</a><img class="img_indicador" src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-indicador.png"/>
# </li>
# <li>
# <a href="/wps/portal/empresas/nuevo" id="empresas-volver-head" title="Empresas">
# <i class="icono empresas"></i>Empresas
#                     </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <!--tipo-acceso-->
# <div class="three columns column-info-corporativa">
# <!-- Escritorio -->
# <div class="info-corporativa info-corporativa-desktop">
# <ul>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li>
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# <!-- Móvil -->
# <div class="info-corporativa info-corporativa-mobile">
# <ul class="gallery js-flickity flickity-enabled is-draggable" data-flickity-options='{ "wrapAround": false }' tabindex="0">
# <div class="flickity-viewport" style="height: 17px;"><div class="flickity-slider" style="left: 0px;"><li class="gallery-cell is-selected" style="position: absolute; left: 0%;">
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li><li aria-hidden="true" class="gallery-cell" style="position: absolute; left: 65%;">
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li><li aria-hidden="true" class="gallery-cell" style="position: absolute; left: 130%;">
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li></div></div><button aria-label="Previous" class="flickity-button flickity-prev-next-button previous" disabled="" type="button"><svg class="flickity-button-icon" viewbox="0 0 100 100"><path class="arrow" d="M 10,50 L 60,100 L 70,90 L 30,50  L 70,10 L 60,0 Z"></path></svg></button><button aria-label="Next" class="flickity-button flickity-prev-next-button next" type="button"><svg class="flickity-button-icon" viewbox="0 0 100 100"><path class="arrow" d="M 10,50 L 60,100 L 70,90 L 30,50  L 70,10 L 60,0 Z" transform="translate(100, 100) rotate(180) "></path></svg></button><ol class="flickity-page-dots"><li aria-current="step" aria-label="Page dot 1" class="dot is-selected"></li><li aria-label="Page dot 2" class="dot"></li><li aria-label="Page dot 3" class="dot"></li></ol></ul>
# </div>
# </div>
# <div class="two columns column-despliegue-login">
# <div class="despliegue-login">
# <a class="mostrar-login" href="#" id="personas-ingresar" onclick="openIframe('https://transacciones.davivienda.com/transaccional/personas/nuevo/login.jsf');abrirPopUpSeguridad(); event.preventDefault();" title="Ingresar"><i class="icono login"></i>Ingreso
#                 <br/>Clientes
#               </a>
# </div>
# </div>
# <!--despliegue-login-->
# </div>
# <div class="aqui-puedo">
# <div class="wrap container">
# <a class="desplegar-aqui-puedo" href="#" id="desplegable-aqui-puedo" title="Aquí puedo">
# </a>
# <div class="buscador">
# <!-- Mostrar Enlace en lugar de Input -->
# <a href="/wps/portal/personas/nuevo/personas/Atencionenlinea" id="BtnAtencionenlinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_atencion_linea_nuevo" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Atención en línea</span>
# </a>
# <a href="/wps/portal/personas/nuevo/personas/aqui_puedo/pagar_facilmente/pse/" id="BtnPagosEnLinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_pagos_en_linea_PSE" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Pagos en línea y PSE</span>
# </a>
# </div>
# </div>
# <nav class="aqui-puedo">
# <!-- <a rel="dynamic-content" href="dyn-cs:id:ThemePersonas_tabNav"></a> -->
# <!--SESSION COOKIE-->
# <div class="wrap menu" style="max-width:1170px; width: 100%;">
# <!--menú normal -->
# <div id="iterator_menu"><div class="row" id="row_0" style="overflow:hidden;"><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono casa"></i>
# 																					Construir mi futuro
# 																				</li>
# <li style="height: auto;">Paso a paso le ayudamos en el Crecimiento de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																						Vivienda
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																						Vehículo
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																						Inversiones
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																						Pensión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																						Educación
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																						Ahorros
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono dinero"></i>
# 																					Manejar mi dinero
# 																				</li>
# <li style="height: auto;">Desde una cuenta de ahorros hasta un portafolio completo de servicios.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																						Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																						Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																						Planeación de Impuestos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																						Tarjetas Débito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																						Giros Directos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																						Giros internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono compra"></i>
# 																					Alcanzar lo que quiero
# 																				</li>
# <li style="height: auto;">Crédito de consumo que se adapta a sus necesidades.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																						Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																						Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																						Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																						Crédito Fractionals
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																						Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono tarjeta"></i>
# 																					Comprar lo que deseo
# 																				</li>
# <li style="height: auto;">Las Tarjetas de Crédito Davivienda le sirven para todo incluso para comprar.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																						Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																						Mundo Diners
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																						Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																						Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																						Compras virtuales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div></div><div class="row" id="row_4" style="overflow:hidden;"><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono familia"></i>
# 																					Respaldar a mi familia
# 																				</li>
# <li style="height: auto;">Productos pensandos para apoyar a los que más quiere.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																						Portafolio Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																						Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																						Cuenta Niños
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																						Tarjeta Mujer
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																						Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono grafico"></i>
# 																					Administrar mis inversiones
# 																				</li>
# <li style="height: auto;">Banca Patrimonial, una asesoría profesional en el manejo de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																						Davivienda Colombia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																						Davivienda Panamá
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																						Davivienda Miami
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																						Davivienda Corredores
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																						Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono proteger"></i>
# 																					Proteger mi patrimonio
# 																				</li>
# <li style="height: auto;">Aquí le ayudamos a asegurar todo lo que ha construido.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																						Seguros para Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																						Seguros para Bienes
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																						Seguros para Casa
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																						Seguros para Carro
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																						Asistencias
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono pagar"></i>
# 																					Pagar fácilmente
# 																				</li>
# <li style="height: auto;">Realice de forma sencilla el pago de sus obligaciones.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																						Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																						Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																						Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																						Transferencias Automaticas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS4" id="menu-personas-comprar-con-codigo-qr" onclick="var nm='Comprar con código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Comprar con código QR">
# 																						Comprar con código QR
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS5" id="menu-personas-vender-con-codigo-qr" onclick="var nm='Vender con Código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vender con Código QR">
# 																						Vender con Código QR
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div></div></div>
# <!--menú responsive-->
# <div class="accordion" id="responsive_menu">
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# 																				Construir mi futuro
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																							Vivienda
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																							Vehículo
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																							Inversiones
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																							Pensión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																							Educación
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																							Ahorros
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1065">
# 																				Manejar mi dinero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1065">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																							Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																							Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																							Planeación de Impuestos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																							Tarjetas Débito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																							Giros Directos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																							Giros internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# 																				Alcanzar lo que quiero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																							Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																							Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																							Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																							Crédito Fractionals
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																							Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# 																				Comprar lo que deseo
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																							Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																							Mundo Diners
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																							Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																							Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																							Compras virtuales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# 																				Respaldar a mi familia
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																							Portafolio Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																							Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																							Cuenta Niños
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																							Tarjeta Mujer
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																							Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# 																				Administrar mis inversiones
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																							Davivienda Colombia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# ...
# <ul class="opciones-usuario">
# <li><a href="https://daviplata.com" title="Inicio"><i class="icon-ap ico-conocer"></i>Conocer <span>DaviPlata</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/Educacion_Financiera/" title="Inicio"><i class="icon-ap ico-aprender"></i>Educación  <span>Financiera</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/asesorarme_si_vivo_o_viajo_al_exterior/" title="Inicio"><i class="icon-ap ico-asesorame"></i>Asesorarme <span>si vivo o viajo al exterior</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor" title="Inicio"><i class="icon-ap ico-aprender"></i>Defensor del  <span>consumidor financiero</span></a></li>
# </ul>
# </div>
# <script type="text/javascript">
#     $(function() {
#         var opcionesUsuario = $('#divItemInferiorM').children('ul');
#         if (typeof opcionesUsuario === "undefined") {
#         	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#         } else {
#           	if ( opcionesUsuario.length <= 0 ) {
#             	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#           	}
#         }
#     });
# </script>
# <script type="text/javascript">
#
# function abrirPopUpSeguridad(){
#
#     var IE = 9
#     var MZ = 14
#     var GC = 41
#
# 	var browser = get_browser_info();
#
# 	/*Internet Explorer*/
# 	if (navigator.userAgent.indexOf('MSIE') !=-1 && browser.version >= IE) {
# 	    abrirPopUp();
# 	}
# 	/*Mozilla Firefox*/
# 	else if (navigator.userAgent.indexOf('Firefox') !=-1 && browser.version >= MZ) {
# 		abrirPopUp();
# 	}
# 	/*Google Chrome*/
# 	else if (navigator.userAgent.indexOf('Chrome') !=-1 && browser.version >= GC) {
# 		abrirPopUp();
# 	}
#
# };
#
# function get_browser_info(){
#     var ua=navigator.userAgent,tem,M=ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#     if(/trident/i.test(M[1])){
#         tem=/\brv[ :]+(\d+)/g.exec(ua) || [];
#         return {name:'IE',version:(tem[1]||'')};
#         }
#     if(M[1]==='Chrome'){
#         tem=ua.match(/\bOPR\/(\d+)/);
#         if(tem!=null)   {return {name:'Opera', version:tem[1]};}
#         }
#     M=M[2]? [M[1], M[2]]: [navigator.appName, navigator.appVersion, '-?'];
#     if((tem=ua.match(/version\/(\d+)/i))!=null) {M.splice(1,1,tem[1]);}
#     return {
#       name: M[0],
#       version: M[1]
#     };
# }
#
# var notificacion = false;
#
# function abrirPopUp(){
#     if (!isMobile) {
#     	/*var scroll = 0;
#     	$('div.contenedor-ifrm-popup-seguridad').bPopup({
#     		position: ['auto', scroll ],
#     		positionStyle: 'fixed'
# 	});*/
# }}
#
# </script>
# </div>
# </section> </div>
# </td>
# </tr>
# <tr>
# <td style="width:100%;" valign="top">
# <div class="component-control id-Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"><span id="Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"></span><section class="ibmPortalControl wpthemeNoSkin a11yRegionTarget" role="region">
# <!-- marks the node the analytics tags for this portlet will be placed in -->
# <div class="asa.portlet" id="asa.portlet.Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1" style="display:none;">
# <span class="asa.portlet.id">Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1</span>
# </div>
# <!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# <div style="position:relative; z-index: 1;">
# <div class="analytics.overlay"></div>
# </div>
# <!-- Hide the text of the title, but still provide the lm-dynamic-title container for accessing the dynamic title -->
# <span class="wpthemeAccess">
# <span class="lm-dynamic-title asa.portlet.title a11yRegionLabel"><span dir="ltr" lang="en">Web Content Viewer</span></span>
# </span>
# <div class="wpthemeOverflowAuto"> <!-- lm:control dynamic spot injects markup of layout control -->
# <style>
#  /*div.wrap { */
#   /* top: 0px; */
#   /* margin-top: 0% !important;*/
#   /* }*/
#  p.destacado {
#
#   margin: 0 0 15px !important;
#
#
# }
# </style>
# <div anchor="d9757fe6-bb27-45ea-9357-823822aae8a2" class="section mobile fp-section fp-table" data-image="/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK" order="1.0" style="display: block; background-image: url(https://www.davivienda.com/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK); height: 300px; padding-top: 15%; margin-top: 304px; min-height: 400px;"><div class="fp-tableCell" style="height: 300px;">
# <div class="wrap" style="/*margin-left:98px;margin-right:98px;*/">
# <p class="enunciado">Solicite una Tarjeta de</p>
# <p class="destacado"> Crédito Móvil en 5 minutos</p>
# <a class="btn btn-davivienda" href="https://www.daviviendamovil.com/productos/tarjeta-credito-movil?utm_source=dfp-mobile&amp;utm_medium=selfpromoted&amp;utm_campaign=davivienda-principal_slf&amp;utm_content=2021_mobban_na&amp;utm_term=na" id="btn-d9757fe6-bb27-45ea-9357-823822aae8a2" onclick="" title="Quiero saber más">
# <i class="icono ico-boton"></i>Conozca más</a>
# </div>
# </div></div>
# </div>
# </section> </div>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table></section>
# <footer>
# <div class="fat-footer">
# <div class="wrap">
# <a class="btn-cerrar-footer" href="#" title="Cerrar"><i class="icono-cerrar"></i></a>
# <div class="logos">
# <ul>
# <li> <a href="#" title="Emisor BVC comprometido"><img border="0" height="40" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=bvc" width="153"/></a> </li>
# <!--<li> <a href="/wps/portal/personas/nuevo/personas/iso9001" title="System Certificacion SGS" target=""><img src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=sgs" border="0" width="110" height="110"/></a> </li>-->
# <li> <a href="#" title="Fogafín"><img border="0" height="94" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=fogafin" width="102"/></a> </li>
# </ul>
# </div>
# <div class="lineas-atencion">
# <h3>Líneas de Atención</h3>
# <ul dir="ltr">
# <li>Bogota</li>
# <li>338 3838</li>
# <li>resto del país</li>
# <li>018000 123 838</li>
# <li>Celulares Movistar</li>
# <li>Desde Estados Unidos</li>
# <li>18 555 566820</li>
# <li>Desde España</li>
# <li>00 8000 3383838</li>
# </ul>
# </div>
# <div class="links-interes">
# <h3>Links de interés</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuInteres li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuInteres").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuInteres").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuInteres"><li order="2"><a class="Politica de cookies" href="/wps/wcm/connect/personas/003903c8-74d1-496b-9d65-e63c696f2e52/DAV+Politica+de+cookies+03+dmc-jf.pdf?MOD=AJPERES&amp;CVID=mocYnDv">Politica de cookies</a></li><li order="3"><a class="Proteccion de datos personales" href="/wps/wcm/connect/personas/b37a90f3-47a2-49a4-98e8-3fdb85e63fab/AVISO+Y+POLITICA+DE+PRIVACIDAD+DE+DATOS+26092017+F.PDF?MOD=AJPERES&amp;CVID=lY2mqrP">Proteccion de datos personales</a></li><li order="4"><a class="Información para el consumidor" href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor">Información para el consumidor</a></li><li order="5"><a class="Mapa de Sitio" href="/wps/portal/personas/nuevo/personas/mapa_del_sitio">Mapa de Sitio</a></li><li order="6"><a class="Transacciones en canales" href="/wps/wcm/connect/personas/baf799eb-28a4-4f6f-9e77-a21d8a38ef8c/19Abril21_TransaccionesCanales+%281%29+-+Juanita+Barriga+Herrera+Herrera+%281%29.pdf?MOD=AJPERES&amp;CVID=nzT7z9g">Transacciones en canales</a></li><li order="7"><a class="Buzón Virtual" href="https://www.grupobolivar.com.co/buzonvirtual/faces/login.jspx?_afrLoop=284733356685949&amp;_afrWindowMode=0&amp;_adf.ctrl-state=nbphu5xk3_9">Buzón Virtual</a></li><li order="8"><a class="Términos y condiciones" href="/wps/wcm/connect/personas/d1d36687-8b5a-4124-b7d0-7f614f69a3a4/REGLAMENTO+DE+USO+CANAL+www.dav.com.pdf?MOD=AJPERES&amp;CVID=meY-yU0">Términos y condiciones</a></li><li order="9"><a class="Glosario" href="/wps/portal/personas/nuevo/personas/glosario">Glosario</a></li><li order="9"><a class="Trabaje con nosotros" href="https://www.trabajarendavivienda.com">Trabaje con nosotros</a></li></ul>
# </div>
# <div class="portales-davivienda">
# <h3>Portales Davivienda</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuPortales li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuPortales").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuPortales").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuPortales"><li order="1"><a href="https://www.portafoliofamiliadavivienda.com/" title="Portafolio Familia">Portafolio Familia</a></li><li order="2"><a href="https://www.catalogodavipuntos.com/" title="Catálogo Davipuntos">Catálogo Davipuntos</a></li><li order="4"><a href="/wps/portal/personas/nuevo/personas/aqui_puedo/comprar_lo_que_deseo/compras_virtuales" title="Compras Virtuales">Compras Virtuales</a></li><li order="5"><a href="https://www.mundodinersclub.com/" title="Mundo Diners Club">Mundo Diners Club</a></li></ul>
# <ul class="redes-sociales">
# <li><h3>Redes Sociales</h3></li>
# <li><a href="https://www.facebook.com/BancoDavivienda" target="_blank" title="Link a Facebook"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=facebook"/></a></li>
# <li><a href="https://www.youtube.com/user/bancodavivienda" target="_blank" title="Link a Youtube"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=youtube"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="wrap container">
# <a class="mostrar-fat-footer" href="#" onclick="mostrarBtnCerrarFooter()"><img src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-arriba-footer.png"/></a>
# <div class="legales">
# <img alt="Vigilado, Superintendecia Financiera de Colombia" src="/PersonasDaviviendaNewTheme/resources/img/logos/vigilado.png"/>
# <p>Banco Davivienda S.A. todos los derechos reservados 2018.</p>
# </div>
# <h1>Davivienda</h1>
# </div>
# </footer>
# <!-- Contactenos -->
# <div style="display:none;">
# <div class="contenedor-ifrm" data-id="PER" style="height:100%; width:970px;">
# <span class="b-close" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <!-- Solicitar Producto -->
# <div class="padre-contenedor-solicitar">
# <div class="contenedor-solicitar">
# <span class="b-close cerrarSolicitarContenido" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <div style="display:none;">
# <div class="contenedor-ifrm-popup-seguridad" data-id="NOT" style="height:100%; width: 503px; top:15px;">
# <span class="b-close" title="Cerrar">
# <div style="cursor: pointer; position: absolute; top: 9px; right: -30px; width: 50px; height: 50px; background:red; filter: alpha(opacity=0); opacity:0; z-index: 2002;"></div>
# </span>
# <div id="ifrm-popup-seguridad">
# <!--<link type="text/css" href="/wps/contenthandler/dav/themelist/com.davivienda.internet.personas.theme/resources/css/estilos.min.css" rel="stylesheet" />-->
# <style>
# 	div#ifrm-popup-seguridad{
# 	    position: relative;
# 	    z-index: 0;
# 	}
# 	body > div.contenedor-ifrm-popup-seguridad > span > div{
# 		z-index: 1
# 	}
#        	div.modal{
#        		margin: 0px;
#        		width: 580px !important;
#        		background-image: none !important;
#        		padding: 0px;
#        		border: none;
#        		text-align: center;
#        		background-color: transparent;
#        		left: -41px;
#        	}
#        	div.modal div.content-modal a img{
#        		border-radius: 10px;
#        	}
#    </style>
# <div class="modal">
# <div class="content-modal">
# <a href="#" onclick="window.top.location.href='https://seguridad.davivienda.com'">
# <img src="/wps/wcm/connect/personas/c77837a2-29e9-4126-99d9-935aad8921f0/PopUpSeguridadPersonasV2.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-c77837a2-29e9-4126-99d9-935aad8921f0-lzrGOi-" width="499"/>
# </a>
# </div>
# </div>
# </div>
# <!--<iframe id="ifrm-popup-seguridad" src="https://www.davivienda.com/wps/portal/personas/nuevo/personas/notificacion/pop_up_seguridad/" scrolling="no" style="border:0; height:110%; width:100%;"></iframe>-->
# </div>
# </div>
# <!--[if lt IE 9]>
#     <script src="/PersonasDaviviendaNewTheme/resources/js/selectivizr-min.js"></script>
#     <![endif]-->
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.fullPage.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.slimscroll.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.bpopup.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jssor.slider.mini.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.browser.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/hashchange.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/funciones.min.js" type="text/javascript"></script>
# <!--<script type='text/javascript' src="http://maps.googleapis.com/maps/api/js?sensor=false"></script>-->
# <!--<script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/funciones.js"></script>
#     <script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/modal.js"></script>-->
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/accordion.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.4.5.min.js"></script> -->
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.3.2.min.js"></script> -->
# <script type="text/javascript">
#       if(isMobile){
#         $("#BtnSolicitudProductos").css("display","none");
#       }
#     </script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/flickity.pkgd.min.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/iframeResizer.min.js" type="text/javascript"></script>
# <div style="display: none; visibility: hidden;">
# <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script>
# <script type="text/javascript">bk_addPageCtx("day_of_week","6");bk_addPageCtx("month_of_year","April");bk_addPageCtx("utm_source","undefined");bk_addPageCtx("utm_medium","undefined");bk_addPageCtx("utm_campaign","undefined");bk_addPageCtx("utm_content","undefined");bk_addPageCtx("utm_term","undefined");bk_doJSTag(42488,1);</script>
# </div><div style="display: none; visibility: hidden;"><script type="text/javascript">var _elqQ=_elqQ||[];_elqQ.push(["elqSetSiteId","1585023691"]);_elqQ.push(["elqTrackPageView"]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="//img03.en25.com/i/elqCfg.min.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script><iframe src="https://tpc.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe><iframe src="https://fdf3728cb7fad25bdf4871968125d159.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe></div><iframe id="google_osd_static_frame_3305461495183" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe></body>

# %% [markdown]
# **Cuando usamos la función execute_script, Python hace el rendering de la página por medio del webdriver seleccionado (Phantom o Chrome)**

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <head>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="//img03.en25.com/i/elqCfg.min.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-955ZS6ZPLE&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script data-dtconfig="app=6e3a0d00a63302d9|rcdec=1209600000|featureHash=ICA27SVfgjqruvx|vcv=2|rdnt=1|uxrgce=1|srcss=1|bp=2|srmcrv=10|cuc=vrbxqx1s|mel=100000|dpvc=1|ssv=4|lastModification=1619184233658|dtVersion=10213210407103252|srmcrl=1|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js|reportUrl=/wps/rb_esd62814|rid=RID_-1900635789|rpid=1883729298|domain=davivienda.com" src="/wps/ruxitagentjs_ICA27SVfgjqruvx_10213210407103252.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1604516209591|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=1920628608" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|vcv=2|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|dpvc=1|md=mdcc1=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar,mdcc2=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1)|lastModification=1593703949302|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/rb_esd62814|rid=RID_-796415603|rpid=1593767469" src="/wps/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><script data-dtconfig="app=ea7c4b59f27d43eb|featureHash=ICA27SVdefghijmoqruvx|rdnt=1|uxrgce=1|bp=2|cuc=vrbxqx1s|srms=1,1,,,|uxrgcm=100,25,300,3;100,25,300,3|dpvc=1|md=1=a.sesion ^rb ul:nth-child(1) ^rb li:nth-child(1) ^rb span:nth-child(1),2=a#header_home2 ^rb div.userNotificationBar ^rb div.nameNotiBar|lastModification=1585505567596|dtVersion=10181191119154660|tp=500,50,0,1|uxdcw=1500|agentUri=/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js|reportUrl=/wps/mypoc/rb_esd62814|rid=RID_-796415603|rpid=-782598794" src="/wps/mypoc/ruxitagentjs_ICA27SVdefghijmoqruvx_10181191119154660.js" type="text/javascript"></script><link href="/PersonasDaviviendaNewTheme/images/faviconDav.ico" rel="icon" type="image/x-icon"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/jquery.fullPage.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/normalize.css" rel="stylesheet"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/skeleton.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/estilos.min.css" rel="stylesheet" type="text/css"/>
# <link href="/PersonasDaviviendaNewTheme/resources/css/responsive_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/flickity.min.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/estilos-wps9.css" rel="stylesheet" type="text/css"/>
# <link href="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/css/s-pagos-pse.css" rel="stylesheet" type="text/css"/>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/modernizr.js" type="text/javascript"></script>
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - INICIO -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/easyXDM.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/openIframe.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/openIframe.js"></script>-->
# <!-- IBM - MENSAJERÍA CROSSDOMAIN - FIN -->
# <!-- Can run Adserver validation -->
# <script src="/PersonasDaviviendaNewTheme/resources/js/ads.min.js"></script>
# <!-- End run Adserver validation -->
# <script type="text/javascript">
#
#     var divAdserverId = 'div-gpt-ad-1499960009335-0';
#       var getGpt = false;
#       var isMobile = false; //initiate as false
#       // device detection
#       if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|ipad|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(navigator.userAgent) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(navigator.userAgent.substr(0,4)))
#         isMobile = true;
#
#       function iframeHeight(height) {
#         $('#ifrm-contenedor').height(height + 100);
#       }
#       function mostrarBtnCerrarFooter () {
#         $('a.btn-cerrar-footer').css('top','');
#         $('a.btn-cerrar-footer').css('top','-30px;');
#       }
#       $(document).on("ready",function(){
#         $("#row_8").css("display","none");
#       });
#     var gtmFn = function () {
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGtm = $.ajax({
#         type:'GET',
#         url:'https://www.googletagmanager.com/gtm.js?id=GTM-WVX9Z5',
#         data:null,
#         timeout: 1000,
#         success:function(){
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-WVX9Z5');
#         adserverFn();
#         },
#       error: function(xmlhttprequest, textstatus, message) {
#         if(textstatus==="timeout") {
#           console.error("cannot load GTM libs");
#           element.css('background-image', 'url(' + image + ')');
#         } else {
#           console.error("something happened and cannot load GTM libs");
#         }
#       },
#         dataType:'script'
#       });
#
#     };
#     var adserverFn = function(){
#       var element = $('div[order="1.0"]');
#       var image = element.attr('data-image');
#       var banner = $("#fullpage div.section[anchor='cc644b6e-41c6-4827-8484-267ad854c4b2']");
#       var ajaxGpt = $.ajax({
#       type:'GET',
#         url:'https://www.googletagservices.com/tag/js/gpt.js',
#         data:null,
#           timeout: 1000,
#         success:function(){
#          getGpt = true;
#          console.debug("success callback exec");
#         },
#         error: function(xmlhttprequest, textstatus, message) {
#           if(textstatus==="timeout") {
#               console.error("cannot load Adserver libs");
#         console.log(xmlhttprequest);
#         console.log(message);
#               element.css('background-image', 'url(' + image + ')');
#           } else {
#               console.error("something happened and cannot load Adserver libs");
#           }
#         },
#         dataType:'script'
#       });
#       var googletag = googletag || {};
#     var matriz =[[1366,768 ],[1920,1080],[1600,900 ],[1440,900 ],[1280,800 ],[1280,1024],[1360,768 ],[1024,768 ],[1280,720 ],[1536,864 ],[1680,1050],[1093,615 ],[2560,1440],[1280,768 ],[1024,600 ],[360,640  ],[1920,1200],[1093,614 ],[1152,720 ],[1152,864 ],[1301,731 ],[1024,820 ],[1438,808 ],[1280,960 ],[1518,853 ],[1242,698 ],[1344,840 ],[1607,904 ]];
#     var idx = -1;
#     var ancho=0;
#     var alto=0;
#     for (i = 0; i < matriz.length; i++) {
#       ancho=parseInt(matriz[i][0]);
#       alto = parseInt(matriz[i][1]);
#       if (ancho ==parseInt(screen.width) && alto ==parseInt(screen.height)){
#         idx= 0;
#          break;
#       }
#     }
#       googletag.cmd = googletag.cmd || [];
#
#       if( window.canRunAds === true ){
#     if (idx !=  -1){
#         ajaxGpt.then(function(){
#         console.debug("then ajaxGpt callback exec");
#             banner.empty();
#         banner.append("<div id='" + divAdserverId + "' ></div>");
#       var elementAds = $( '#'+divAdserverId );
#       elementAds.find('div').css("height", window.innerHeight);
#       elementAds.find('div').css("width", window.innerWidth);
#       elementAds.find('iframe').css("height", window.innerHeight);
#       elementAds.find('iframe').css("width", window.innerWidth);
#         });
#       }else{
#         element.css('background-image', 'url(' + image + ')');
#       }
#     }
#     else{
#         element.css('background-image', 'url(' + image + ')');
#     }
#     };
#    </script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   </script>
# <script>
#     googletag.cmd.push(function() {
#
#
#       /* DEFINE SLOT */
#       googletag.defineSlot('/236880650/Home_Daviviendacombanner', [screen.width,screen.height], divAdserverId).addService(googletag.pubads()).
#       addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs(true);
#       googletag.enableServices();
#       });
#       googletag.cmd.push(function() { googletag.display(divAdserverId);});
#
#
#   </script>
# <meta content="A+b/H0b8RPXNaJgaNFpO0YOFuGK6myDQXlwnJB3SwzvNMfcndat4DZYMrP4ClJIzYWo3/yP2S+8FTZ/lpqbPAAEAAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MjYyMjA3OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="A7+rMYR5onPnACrz+niKSeFdH3xw1IyHo2AZSHmxrofRk9w4HcQPMYcpBUKu6OQ6zsdxf4m/vqa6tG6Na4OLpAQAAAB4eyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiQ29udmVyc2lvbk1lYXN1cmVtZW50IiwiZXhwaXJ5IjoxNjI2MjIwNzk5LCJpc1RoaXJkUGFydHkiOnRydWV9" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021042001.js"></script><link href="https://adservice.google.com/adsid/integrator.js?domain=www.davivienda.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.davivienda.com" type="text/javascript"></script></head>
# <body onload="gtmFn()" style="overflow: hidden; height: 100%;">
# <!-- <body> -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>&lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WVX9Z5" height="auto !important" width="100%" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- JPG - LOADING SCREEN - INICIO -->
# <div class="loadingScreen">
# <img src="/PersonasDaviviendaNewTheme/resources/img/iconos/loadingScreenIcon.gif"/>
# </div>
# <!-- JPG - LOADING SCREEN - FIN -->
# <header>
# <div class="login">
# <div class="wrap">
# <div class="form" style="width:100%;padding:0px;">
# <div id="divIFrame" style="border:none;overflow:hidden;height: 310px; width: 100%;display:block;">
# </div>
# <a class="btn-cerrar" href="#" id="personas-cerrar-ingresar" title="Cerrar"><i class="icono-cerrar"></i></a>
# </div>
# </div>
# </div>
# <div class="cabecera">
# <div class="wrap container">
# <div class="four columns">
# <a class="current" href="/wps/portal/personas/nuevo" id="personas-volver-head" title="Volver a Home personas"><h1>Davivienda</h1></a>
# </div>
# <div class="three columns">
# <div class="tipo-acceso">
# <nav class="acceso">
# <ul>
# <li>
# <a class="activo" href="#" title="Personas">
# <i class="icono personas"></i>Personas</a><img class="img_indicador" src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-indicador.png"/>
# </li>
# <li>
# <a href="/wps/portal/empresas/nuevo" id="empresas-volver-head" title="Empresas">
# <i class="icono empresas"></i>Empresas
#                     </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <!--tipo-acceso-->
# <div class="three columns column-info-corporativa">
# <!-- Escritorio -->
# <div class="info-corporativa info-corporativa-desktop">
# <ul>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li>
# <li>
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li>
# <li>
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li>
# </ul>
# </div>
# <!-- Móvil -->
# <div class="info-corporativa info-corporativa-mobile">
# <ul class="gallery js-flickity flickity-enabled is-draggable" data-flickity-options='{ "wrapAround": false }' tabindex="0">
# <div class="flickity-viewport" style="height: 17px;"><div class="flickity-slider" style="left: 0px;"><li class="gallery-cell is-selected" style="position: absolute; left: 0%;">
# <a href="/wps/portal/personas/nuevo/personas/quienes_somos/sobre_nosotros">¿Quiénes somos?</a>
# </li><li aria-hidden="true" class="gallery-cell" style="position: absolute; left: 65%;">
# <a href="https://ir.davivienda.com">Información para inversionistas</a>
# </li><li aria-hidden="true" class="gallery-cell" style="position: absolute; left: 130%;">
# <a href="/wps/portal/personas/nuevo/personas/informacion_adicional">Información adicional</a>
# </li></div></div><button aria-label="Previous" class="flickity-button flickity-prev-next-button previous" disabled="" type="button"><svg class="flickity-button-icon" viewbox="0 0 100 100"><path class="arrow" d="M 10,50 L 60,100 L 70,90 L 30,50  L 70,10 L 60,0 Z"></path></svg></button><button aria-label="Next" class="flickity-button flickity-prev-next-button next" type="button"><svg class="flickity-button-icon" viewbox="0 0 100 100"><path class="arrow" d="M 10,50 L 60,100 L 70,90 L 30,50  L 70,10 L 60,0 Z" transform="translate(100, 100) rotate(180) "></path></svg></button><ol class="flickity-page-dots"><li aria-current="step" aria-label="Page dot 1" class="dot is-selected"></li><li aria-label="Page dot 2" class="dot"></li><li aria-label="Page dot 3" class="dot"></li></ol></ul>
# </div>
# </div>
# <div class="two columns column-despliegue-login">
# <div class="despliegue-login">
# <a class="mostrar-login" href="#" id="personas-ingresar" onclick="openIframe('https://transacciones.davivienda.com/transaccional/personas/nuevo/login.jsf');abrirPopUpSeguridad(); event.preventDefault();" title="Ingresar"><i class="icono login"></i>Ingreso
#                 <br/>Clientes
#               </a>
# </div>
# </div>
# <!--despliegue-login-->
# </div>
# <div class="aqui-puedo">
# <div class="wrap container">
# <a class="desplegar-aqui-puedo" href="#" id="desplegable-aqui-puedo" title="Aquí puedo">
# </a>
# <div class="buscador">
# <!-- Mostrar Enlace en lugar de Input -->
# <a href="/wps/portal/personas/nuevo/personas/Atencionenlinea" id="BtnAtencionenlinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_atencion_linea_nuevo" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Atención en línea</span>
# </a>
# <a href="/wps/portal/personas/nuevo/personas/aqui_puedo/pagar_facilmente/pse/" id="BtnPagosEnLinea" target="_blank">
# <img border="0" height="37" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=Icono_pagos_en_linea_PSE" width="37"/>
# <span class="link-preguntasFrecuentes link-preguntasFrecuentes-update">Pagos en línea y PSE</span>
# </a>
# </div>
# </div>
# <nav class="aqui-puedo">
# <!-- <a rel="dynamic-content" href="dyn-cs:id:ThemePersonas_tabNav"></a> -->
# <!--SESSION COOKIE-->
# <div class="wrap menu" style="max-width:1170px; width: 100%;">
# <!--menú normal -->
# <div id="iterator_menu"><div class="row" id="row_0" style="overflow:hidden;"><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono casa"></i>
# 																					Construir mi futuro
# 																				</li>
# <li style="height: auto;">Paso a paso le ayudamos en el Crecimiento de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																						Vivienda
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																						Vehículo
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																						Inversiones
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																						Pensión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																						Educación
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																						Ahorros
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono dinero"></i>
# 																					Manejar mi dinero
# 																				</li>
# <li style="height: auto;">Desde una cuenta de ahorros hasta un portafolio completo de servicios.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																						Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																						Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																						Planeación de Impuestos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																						Tarjetas Débito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																						Giros Directos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																						Giros internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono compra"></i>
# 																					Alcanzar lo que quiero
# 																				</li>
# <li style="height: auto;">Crédito de consumo que se adapta a sus necesidades.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																						Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																						Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																						Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																						Crédito Fractionals
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																						Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono tarjeta"></i>
# 																					Comprar lo que deseo
# 																				</li>
# <li style="height: auto;">Las Tarjetas de Crédito Davivienda le sirven para todo incluso para comprar.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																						Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																						Mundo Diners
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																						Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																						Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																						Compras virtuales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div></div><div class="row" id="row_4" style="overflow:hidden;"><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono familia"></i>
# 																					Respaldar a mi familia
# 																				</li>
# <li style="height: auto;">Productos pensandos para apoyar a los que más quiere.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																						Portafolio Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																						Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																						Cuenta Niños
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																						Tarjeta Mujer
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																						Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono grafico"></i>
# 																					Administrar mis inversiones
# 																				</li>
# <li style="height: auto;">Banca Patrimonial, una asesoría profesional en el manejo de su patrimonio.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																						Davivienda Colombia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH7" id="menu-personas-davivienda-panama" onclick="var nm='Davivienda Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Panamá">
# 																						Davivienda Panamá
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3IH5" id="menu-personas-davivienda-miami" onclick="var nm='Davivienda Miami'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Miami">
# 																						Davivienda Miami
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I94" id="menu-personas-davivienda-corredores" onclick="var nm='Davivienda Corredores'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Corredores">
# 																						Davivienda Corredores
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3I96" id="menu-personas-corredores-asociados-panama" onclick="var nm='Corredores Asociados Panamá'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Corredores Asociados Panamá">
# 																						Corredores Asociados Panamá
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono proteger"></i>
# 																					Proteger mi patrimonio
# 																				</li>
# <li style="height: auto;">Aquí le ayudamos a asegurar todo lo que ha construido.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU4" id="menu-personas-seguros-para-familia" onclick="var nm='Seguros para Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Familia">
# 																						Seguros para Familia
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GU7" id="menu-personas-seguros-para-bienes" onclick="var nm='Seguros para Bienes'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Bienes">
# 																						Seguros para Bienes
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G15" id="menu-personas-seguros-para-casa" onclick="var nm='Seguros para Casa'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Casa">
# 																						Seguros para Casa
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GH6" id="menu-personas-seguros-para-carro" onclick="var nm='Seguros para Carro'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Seguros para Carro">
# 																						Seguros para Carro
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82N09K70Q2L4CKUJ00J3" id="menu-personas-asistencias" onclick="var nm='Asistencias'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias">
# 																						Asistencias
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="three columns" style="width:22%; margin-left:3%;">
# <ul style="width:100%">
# <li>
# <i class="icono pagar"></i>
# 																					Pagar fácilmente
# 																				</li>
# <li style="height: auto;">Realice de forma sencilla el pago de sus obligaciones.</li>
# <li>
# <ul>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18F2" id="menu-personas-mis-pagos-automaticos" onclick="var nm='Mis Pagos Automaticos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mis Pagos Automaticos">
# 																						Mis Pagos Automaticos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O18V3" id="menu-personas-pagos-en-linea-y-pse" onclick="var nm='Pagos en Línea y PSE'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pagos en Línea y PSE">
# 																						Pagos en Línea y PSE
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1O01" id="menu-personas-servicios-de-informacion-y-pagos" onclick="var nm='Servicios de Información y Pagos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Servicios de Información y Pagos">
# 																						Servicios de Información y Pagos
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAUP190ATK6OP9O2843" id="menu-personas-transferencias-automaticas" onclick="var nm='Transferencias Automaticas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Transferencias Automaticas">
# 																						Transferencias Automaticas
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS4" id="menu-personas-comprar-con-codigo-qr" onclick="var nm='Comprar con código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Comprar con código QR">
# 																						Comprar con código QR
# 																						</a>
# </li>
# <li class="list-cnt">
# <a href="?uri=nm:oid:Z6_NH941K82NOJ400QDSLEHMEICS5" id="menu-personas-vender-con-codigo-qr" onclick="var nm='Vender con Código QR'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vender con Código QR">
# 																						Vender con Código QR
# 																						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div></div></div>
# <!--menú responsive-->
# <div class="accordion" id="responsive_menu">
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# 																				Construir mi futuro
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O10K3">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10S1" id="menu-personas-vivienda" onclick="var nm='Vivienda'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vivienda">
# 																							Vivienda
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1022" id="menu-personas-vehiculo" onclick="var nm='Vehículo'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Vehículo">
# 																							Vehículo
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I0" id="menu-personas-inversiones" onclick="var nm='Inversiones'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Inversiones">
# 																							Inversiones
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10I5" id="menu-personas-pension" onclick="var nm='Pensión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Pensión">
# 																							Pensión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10A6" id="menu-personas-educacion" onclick="var nm='Educación'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Educación">
# 																							Educación
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10Q4" id="menu-personas-ahorros" onclick="var nm='Ahorros'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Ahorros">
# 																							Ahorros
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1065">
# 																				Manejar mi dinero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1065">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O10V5" id="menu-personas-portafolio-banca-personal" onclick="var nm='Portafolio Banca Personal'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Banca Personal">
# 																							Portafolio Banca Personal
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G06" id="menu-personas-cuentas-transaccionales" onclick="var nm='Cuentas Transaccionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuentas Transaccionales">
# 																							Cuentas Transaccionales
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M16O3" id="menu-personas-planeacion-de-impuestos" onclick="var nm='Planeación de Impuestos'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Planeación de Impuestos">
# 																							Planeación de Impuestos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MCO250AMMBDD7M1641" id="menu-personas-tarjetas-debito" onclick="var nm='Tarjetas Débito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Débito">
# 																							Tarjetas Débito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_H29IG282N0LE50Q802BCCF06T3" id="menu-personas-giros-directos-" onclick="var nm='Giros Directos '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros Directos ">
# 																							Giros Directos
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_NH941K82NOOM00QIMPGRARGF47" id="menu-personas-giros-internacionales-" onclick="var nm='Giros internacionales '; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros internacionales ">
# 																							Giros internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# 																				Alcanzar lo que quiero
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G85">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1G87" id="menu-personas-creditos-de-libre-inversion" onclick="var nm='Créditos de Libre Inversión'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Créditos de Libre Inversión">
# 																							Créditos de Libre Inversión
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GO5" id="menu-personas-credito-descontado-de-nomina" onclick="var nm='Crédito Descontado de Nómina'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Descontado de Nómina">
# 																							Crédito Descontado de Nómina
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9S17" id="menu-personas-credito-compra-de-cartera" onclick="var nm='Crédito Compra de Cartera'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Compra de Cartera">
# 																							Crédito Compra de Cartera
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SP5" id="menu-personas-credito-fractionals" onclick="var nm='Crédito Fractionals'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Fractionals">
# 																							Crédito Fractionals
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O9SL0" id="menu-personas-credito-zuana" onclick="var nm='Crédito Zuana'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Crédito Zuana">
# 																							Crédito Zuana
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# 																				Comprar lo que deseo
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GK4">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GK6" id="menu-personas-tarjeta-de-credito" onclick="var nm='Tarjeta de Crédito'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta de Crédito">
# 																							Tarjeta de Crédito
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE0" id="menu-personas-mundo-diners" onclick="var nm='Mundo Diners'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Mundo Diners">
# 																							Mundo Diners
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GC7" id="menu-personas-tarjetas-prepago-y-ecard" onclick="var nm='Tarjetas Prepago y Ecard'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Prepago y Ecard">
# 																							Tarjetas Prepago y Ecard
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GS5" id="menu-personas-asistencias-y-beneficios" onclick="var nm='Asistencias y Beneficios'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Asistencias y Beneficios">
# 																							Asistencias y Beneficios
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3DU6" id="menu-personas-compras-virtuales" onclick="var nm='Compras virtuales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Compras virtuales">
# 																							Compras virtuales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# 																				Respaldar a mi familia
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1G26">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2M4PO70AEDIBV6B3UE2" id="menu-personas-portafolio-familia" onclick="var nm='Portafolio Familia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Portafolio Familia">
# 																							Portafolio Familia
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GI6" id="menu-personas-tarjetas-amparadas" onclick="var nm='Tarjetas Amparadas'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjetas Amparadas">
# 																							Tarjetas Amparadas
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA4" id="menu-personas-cuenta-ninos" onclick="var nm='Cuenta Niños'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Cuenta Niños">
# 																							Cuenta Niños
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GA7" id="menu-personas-tarjeta-mujer" onclick="var nm='Tarjeta Mujer'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Tarjeta Mujer">
# 																							Tarjeta Mujer
# 																						</a>
# </li>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_4GIL1E6PAM0A80AF47H8N30G93" id="menu-personas-giros-y-transferencias-internacionales" onclick="var nm='Giros y Transferencias Internacionales'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Giros y Transferencias Internacionales">
# 																							Giros y Transferencias Internacionales
# 																						</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="accordion-section">
# <a class="accordion-section-title" href="#Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# 																				Administrar mis inversiones
# 																			</a>
# <div class="accordion-section-content" id="Z6_38Q4NJB2MSF930AM0SCA9O1GQ5">
# <ul>
# <li class="accordion_list">
# <a href="?uri=nm:oid:Z6_38Q4NJB2MSF930AM0SCA9O1GQ7" id="menu-personas-davivienda-colombia" onclick="var nm='Davivienda Colombia'; ga('send','event', 'Personas', nm.replace(/\s/g , '_') , 'Menu_aqui_puedo');" title="Davivienda Colombia">
# 																							Davivienda Colombia
# 																						</a>
# </li>
# <li class="accordion_list">
# ...
# <ul class="opciones-usuario">
# <li><a href="https://daviplata.com" title="Inicio"><i class="icon-ap ico-conocer"></i>Conocer <span>DaviPlata</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/Educacion_Financiera/" title="Inicio"><i class="icon-ap ico-aprender"></i>Educación  <span>Financiera</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/aqui_puedo_h/asesorarme_si_vivo_o_viajo_al_exterior/" title="Inicio"><i class="icon-ap ico-asesorame"></i>Asesorarme <span>si vivo o viajo al exterior</span></a></li>
# <li><a href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor" title="Inicio"><i class="icon-ap ico-aprender"></i>Defensor del  <span>consumidor financiero</span></a></li>
# </ul>
# </div>
# <script type="text/javascript">
#     $(function() {
#         var opcionesUsuario = $('#divItemInferiorM').children('ul');
#         if (typeof opcionesUsuario === "undefined") {
#         	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#         } else {
#           	if ( opcionesUsuario.length <= 0 ) {
#             	$('#divItemInferiorM').html('').append( $('.divItemInferiorM-respaldo').html() );
#           	}
#         }
#     });
# </script>
# <script type="text/javascript">
#
# function abrirPopUpSeguridad(){
#
#     var IE = 9
#     var MZ = 14
#     var GC = 41
#
# 	var browser = get_browser_info();
#
# 	/*Internet Explorer*/
# 	if (navigator.userAgent.indexOf('MSIE') !=-1 && browser.version >= IE) {
# 	    abrirPopUp();
# 	}
# 	/*Mozilla Firefox*/
# 	else if (navigator.userAgent.indexOf('Firefox') !=-1 && browser.version >= MZ) {
# 		abrirPopUp();
# 	}
# 	/*Google Chrome*/
# 	else if (navigator.userAgent.indexOf('Chrome') !=-1 && browser.version >= GC) {
# 		abrirPopUp();
# 	}
#
# };
#
# function get_browser_info(){
#     var ua=navigator.userAgent,tem,M=ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#     if(/trident/i.test(M[1])){
#         tem=/\brv[ :]+(\d+)/g.exec(ua) || [];
#         return {name:'IE',version:(tem[1]||'')};
#         }
#     if(M[1]==='Chrome'){
#         tem=ua.match(/\bOPR\/(\d+)/);
#         if(tem!=null)   {return {name:'Opera', version:tem[1]};}
#         }
#     M=M[2]? [M[1], M[2]]: [navigator.appName, navigator.appVersion, '-?'];
#     if((tem=ua.match(/version\/(\d+)/i))!=null) {M.splice(1,1,tem[1]);}
#     return {
#       name: M[0],
#       version: M[1]
#     };
# }
#
# var notificacion = false;
#
# function abrirPopUp(){
#     if (!isMobile) {
#     	/*var scroll = 0;
#     	$('div.contenedor-ifrm-popup-seguridad').bPopup({
#     		position: ['auto', scroll ],
#     		positionStyle: 'fixed'
# 	});*/
# }}
#
# </script>
# </div>
# </section> </div>
# </td>
# </tr>
# <tr>
# <td style="width:100%;" valign="top">
# <div class="component-control id-Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"><span id="Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1"></span><section class="ibmPortalControl wpthemeNoSkin a11yRegionTarget" role="region">
# <!-- marks the node the analytics tags for this portlet will be placed in -->
# <div class="asa.portlet" id="asa.portlet.Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1" style="display:none;">
# <span class="asa.portlet.id">Z7_38Q4NJB2MSOVF0AMDO5J4K3UI1</span>
# </div>
# <!-- asa.overlay marks the node that the AsaOverlayWidget will be placed in -->
# <div style="position:relative; z-index: 1;">
# <div class="analytics.overlay"></div>
# </div>
# <!-- Hide the text of the title, but still provide the lm-dynamic-title container for accessing the dynamic title -->
# <span class="wpthemeAccess">
# <span class="lm-dynamic-title asa.portlet.title a11yRegionLabel"><span dir="ltr" lang="en">Web Content Viewer</span></span>
# </span>
# <div class="wpthemeOverflowAuto"> <!-- lm:control dynamic spot injects markup of layout control -->
# <style>
#  /*div.wrap { */
#   /* top: 0px; */
#   /* margin-top: 0% !important;*/
#   /* }*/
#  p.destacado {
#
#   margin: 0 0 15px !important;
#
#
# }
# </style>
# <div anchor="d9757fe6-bb27-45ea-9357-823822aae8a2" class="section mobile fp-section fp-table" data-image="/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK" order="1.0" style="display: block; background-image: url(https://www.davivienda.com/wps/wcm/connect/personas/8b228182-8734-47a0-94cf-e6b3cd5c17f1/DFP_BG_Mobile.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-8b228182-8734-47a0-94cf-e6b3cd5c17f1-nujaqZK); height: 300px; padding-top: 15%; margin-top: 304px; min-height: 400px;"><div class="fp-tableCell" style="height: 300px;">
# <div class="wrap" style="/*margin-left:98px;margin-right:98px;*/">
# <p class="enunciado">Solicite una Tarjeta de</p>
# <p class="destacado"> Crédito Móvil en 5 minutos</p>
# <a class="btn btn-davivienda" href="https://www.daviviendamovil.com/productos/tarjeta-credito-movil?utm_source=dfp-mobile&amp;utm_medium=selfpromoted&amp;utm_campaign=davivienda-principal_slf&amp;utm_content=2021_mobban_na&amp;utm_term=na" id="btn-d9757fe6-bb27-45ea-9357-823822aae8a2" onclick="" title="Quiero saber más">
# <i class="icono ico-boton"></i>Conozca más</a>
# </div>
# </div></div>
# </div>
# </section> </div>
# </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table></section>
# <footer>
# <div class="fat-footer">
# <div class="wrap">
# <a class="btn-cerrar-footer" href="#" title="Cerrar"><i class="icono-cerrar"></i></a>
# <div class="logos">
# <ul>
# <li> <a href="#" title="Emisor BVC comprometido"><img border="0" height="40" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=bvc" width="153"/></a> </li>
# <!--<li> <a href="/wps/portal/personas/nuevo/personas/iso9001" title="System Certificacion SGS" target=""><img src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=sgs" border="0" width="110" height="110"/></a> </li>-->
# <li> <a href="#" title="Fogafín"><img border="0" height="94" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=fogafin" width="102"/></a> </li>
# </ul>
# </div>
# <div class="lineas-atencion">
# <h3>Líneas de Atención</h3>
# <ul dir="ltr">
# <li>Bogota</li>
# <li>338 3838</li>
# <li>resto del país</li>
# <li>018000 123 838</li>
# <li>Celulares Movistar</li>
# <li>Desde Estados Unidos</li>
# <li>18 555 566820</li>
# <li>Desde España</li>
# <li>00 8000 3383838</li>
# </ul>
# </div>
# <div class="links-interes">
# <h3>Links de interés</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuInteres li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuInteres").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuInteres").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuInteres"><li order="2"><a class="Politica de cookies" href="/wps/wcm/connect/personas/003903c8-74d1-496b-9d65-e63c696f2e52/DAV+Politica+de+cookies+03+dmc-jf.pdf?MOD=AJPERES&amp;CVID=mocYnDv">Politica de cookies</a></li><li order="3"><a class="Proteccion de datos personales" href="/wps/wcm/connect/personas/b37a90f3-47a2-49a4-98e8-3fdb85e63fab/AVISO+Y+POLITICA+DE+PRIVACIDAD+DE+DATOS+26092017+F.PDF?MOD=AJPERES&amp;CVID=lY2mqrP">Proteccion de datos personales</a></li><li order="4"><a class="Información para el consumidor" href="/wps/portal/personas/nuevo/personas/Informacionalconsumidor">Información para el consumidor</a></li><li order="5"><a class="Mapa de Sitio" href="/wps/portal/personas/nuevo/personas/mapa_del_sitio">Mapa de Sitio</a></li><li order="6"><a class="Transacciones en canales" href="/wps/wcm/connect/personas/baf799eb-28a4-4f6f-9e77-a21d8a38ef8c/19Abril21_TransaccionesCanales+%281%29+-+Juanita+Barriga+Herrera+Herrera+%281%29.pdf?MOD=AJPERES&amp;CVID=nzT7z9g">Transacciones en canales</a></li><li order="7"><a class="Buzón Virtual" href="https://www.grupobolivar.com.co/buzonvirtual/faces/login.jspx?_afrLoop=284733356685949&amp;_afrWindowMode=0&amp;_adf.ctrl-state=nbphu5xk3_9">Buzón Virtual</a></li><li order="8"><a class="Términos y condiciones" href="/wps/wcm/connect/personas/d1d36687-8b5a-4124-b7d0-7f614f69a3a4/REGLAMENTO+DE+USO+CANAL+www.dav.com.pdf?MOD=AJPERES&amp;CVID=meY-yU0">Términos y condiciones</a></li><li order="9"><a class="Glosario" href="/wps/portal/personas/nuevo/personas/glosario">Glosario</a></li><li order="9"><a class="Trabaje con nosotros" href="https://www.trabajarendavivienda.com">Trabaje con nosotros</a></li></ul>
# </div>
# <div class="portales-davivienda">
# <h3>Portales Davivienda</h3>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	var array = [];
#
# 	$("#menuPortales li").sort(function(a,b){
# 	    return parseInt($(a).attr("order")) - parseInt($(b).attr("order"));
# 	}).each(function(){
# 		var position = array.length;
# 		array[position] = this;
# 	})
#
# 	$("#menuPortales").empty();
#
# 	for (var i = array.length - 1; i >= 0; i--) {
# 		$("#menuPortales").prepend(array[i]);
# 	};
#
# });
#
# </script>
# <ul id="menuPortales"><li order="1"><a href="https://www.portafoliofamiliadavivienda.com/" title="Portafolio Familia">Portafolio Familia</a></li><li order="2"><a href="https://www.catalogodavipuntos.com/" title="Catálogo Davipuntos">Catálogo Davipuntos</a></li><li order="4"><a href="/wps/portal/personas/nuevo/personas/aqui_puedo/comprar_lo_que_deseo/compras_virtuales" title="Compras Virtuales">Compras Virtuales</a></li><li order="5"><a href="https://www.mundodinersclub.com/" title="Mundo Diners Club">Mundo Diners Club</a></li></ul>
# <ul class="redes-sociales">
# <li><h3>Redes Sociales</h3></li>
# <li><a href="https://www.facebook.com/BancoDavivienda" target="_blank" title="Link a Facebook"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=facebook"/></a></li>
# <li><a href="https://www.youtube.com/user/bancodavivienda" target="_blank" title="Link a Youtube"><img border="0" src="/Documents/wcm?biblio=WCM_INTERNET_PERSONAS&amp;nombre=youtube"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="wrap container">
# <a class="mostrar-fat-footer" href="#" onclick="mostrarBtnCerrarFooter()"><img src="/PersonasDaviviendaNewTheme/resources/img/iconos/ico-arriba-footer.png"/></a>
# <div class="legales">
# <img alt="Vigilado, Superintendecia Financiera de Colombia" src="/PersonasDaviviendaNewTheme/resources/img/logos/vigilado.png"/>
# <p>Banco Davivienda S.A. todos los derechos reservados 2018.</p>
# </div>
# <h1>Davivienda</h1>
# </div>
# </footer>
# <!-- Contactenos -->
# <div style="display:none;">
# <div class="contenedor-ifrm" data-id="PER" style="height:100%; width:970px;">
# <span class="b-close" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <!-- Solicitar Producto -->
# <div class="padre-contenedor-solicitar">
# <div class="contenedor-solicitar">
# <span class="b-close cerrarSolicitarContenido" title="Cerrar"><i class="icono-cerrar-modal"></i></span>
# </div>
# </div>
# <div style="display:none;">
# <div class="contenedor-ifrm-popup-seguridad" data-id="NOT" style="height:100%; width: 503px; top:15px;">
# <span class="b-close" title="Cerrar">
# <div style="cursor: pointer; position: absolute; top: 9px; right: -30px; width: 50px; height: 50px; background:red; filter: alpha(opacity=0); opacity:0; z-index: 2002;"></div>
# </span>
# <div id="ifrm-popup-seguridad">
# <!--<link type="text/css" href="/wps/contenthandler/dav/themelist/com.davivienda.internet.personas.theme/resources/css/estilos.min.css" rel="stylesheet" />-->
# <style>
# 	div#ifrm-popup-seguridad{
# 	    position: relative;
# 	    z-index: 0;
# 	}
# 	body > div.contenedor-ifrm-popup-seguridad > span > div{
# 		z-index: 1
# 	}
#        	div.modal{
#        		margin: 0px;
#        		width: 580px !important;
#        		background-image: none !important;
#        		padding: 0px;
#        		border: none;
#        		text-align: center;
#        		background-color: transparent;
#        		left: -41px;
#        	}
#        	div.modal div.content-modal a img{
#        		border-radius: 10px;
#        	}
#    </style>
# <div class="modal">
# <div class="content-modal">
# <a href="#" onclick="window.top.location.href='https://seguridad.davivienda.com'">
# <img src="/wps/wcm/connect/personas/c77837a2-29e9-4126-99d9-935aad8921f0/PopUpSeguridadPersonasV2.jpg?MOD=AJPERES&amp;CACHEID=ROOTWORKSPACE.Z18_NH941K82NG9J20QGP2BPTN39I7-c77837a2-29e9-4126-99d9-935aad8921f0-lzrGOi-" width="499"/>
# </a>
# </div>
# </div>
# </div>
# <!--<iframe id="ifrm-popup-seguridad" src="https://www.davivienda.com/wps/portal/personas/nuevo/personas/notificacion/pop_up_seguridad/" scrolling="no" style="border:0; height:110%; width:100%;"></iframe>-->
# </div>
# </div>
# <!--[if lt IE 9]>
#     <script src="/PersonasDaviviendaNewTheme/resources/js/selectivizr-min.js"></script>
#     <![endif]-->
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.fullPage.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.slimscroll.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.bpopup.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jssor.slider.mini.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/jquery.browser.min.js" type="text/javascript"></script>
# <script src="/PersonasDaviviendaNewTheme/resources/js/hashchange.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/funciones.min.js" type="text/javascript"></script>
# <!--<script type='text/javascript' src="http://maps.googleapis.com/maps/api/js?sensor=false"></script>-->
# <!--<script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/funciones.js"></script>
#     <script type='text/javascript' src="/PersonasDaviviendaNewTheme/resources/js/modal.js"></script>-->
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/accordion.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.4.5.min.js"></script> -->
# <!-- <script type="text/javascript" src="/PersonasDaviviendaNewTheme/resources/js/jquery.mobile-1.3.2.min.js"></script> -->
# <script type="text/javascript">
#       if(isMobile){
#         $("#BtnSolicitudProductos").css("display","none");
#       }
#     </script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/flickity.pkgd.min.js" type="text/javascript"></script>
# <script src="/wps/contenthandler/dav/fs-type1/themes/DaviviendaPersonasTheme/resources/js/iframeResizer.min.js" type="text/javascript"></script>
# <div style="display: none; visibility: hidden;">
# <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script>
# <script type="text/javascript">bk_addPageCtx("day_of_week","6");bk_addPageCtx("month_of_year","April");bk_addPageCtx("utm_source","undefined");bk_addPageCtx("utm_medium","undefined");bk_addPageCtx("utm_campaign","undefined");bk_addPageCtx("utm_content","undefined");bk_addPageCtx("utm_term","undefined");bk_doJSTag(42488,1);</script>
# </div><div style="display: none; visibility: hidden;"><script type="text/javascript">var _elqQ=_elqQ||[];_elqQ.push(["elqSetSiteId","1585023691"]);_elqQ.push(["elqTrackPageView"]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="//img03.en25.com/i/elqCfg.min.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script><iframe src="https://tpc.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe><iframe src="https://fdf3728cb7fad25bdf4871968125d159.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe></div><iframe id="google_osd_static_frame_3305461495183" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe></body>>

# %% [markdown]
# Ahora sí estamos capturando el código HTML que nos interesa

# %% [markdown]
# ## Otras funcionalidades de Selenium
#
#
#
# - **Selenium nos permite generar códigos en Python que se comporten como un humano en la web** (web bots)
#
#
# - Utilicemos como ejemplo la página web del [Alkosto](https://www.Alkosto.com) y [NewTours](http://demo.guru99.com/test/newtours/)

# %%
browser = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
browser.get("http://demo.guru99.com/test/newtours/")
time.sleep(3)

# %% [markdown]
# **Tipos de Localizadores**
# - **ID**	To find the element by ID of the element
# - **Classname**	To find the element by Classname of the element
# - **Name**	To find the element by name of the element
# - **Link text**	To find the element by text of the link
# - **XPath**	XPath required for finding the dynamic element and traverse between various elements of the web page

# %% [markdown]
# __fuente: https://www.guru99.com/xpath-selenium.html__

# %%
browser = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
browser.get("http://demo.guru99.com/test/newtours/")

time.sleep(3)

texto_usuario = browser.find_element_by_name("userName")
texto_pass = browser.find_element_by_name("password")
boton_submit = browser.find_element_by_name("submit")

texto_usuario.send_keys("SANTIAGOMATALLANA")
time.sleep(4)
texto_pass.send_keys("prueba1234")

time.sleep(4)
boton_submit.click()

print("Terminé")
# Out:
# Terminé

# %%
browser.quit()
print("Prueba completada")
# Out:
# Prueba completada

# %%
browser = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
browser.get("http://demo.guru99.com/test/newtours/")
browser.maximize_window()
time.sleep(3)
browser.find_element_by_link_text("SUPPORT").click()
time.sleep(5)
browser.get("http://demo.guru99.com/test/newtours/")
time.sleep(5)
texto_usuario = browser.find_element_by_name("userName")
texto_pass = browser.find_element_by_name("password")
boton_submit = browser.find_element_by_name("submit")
texto_usuario.send_keys("daniel")
time.sleep(4)
texto_pass.send_keys("prueba")
boton_submit.click()
time.sleep(4)
browser.quit()
print("Prueba completada")
# Out:
# Prueba completada

# %% [markdown]
# Esta vez usaremos Chrome para poder visualizar las acciones que programemos
#
# __Información útil para encontrar elementos con Selenium: https://www.techbeamers.com/locate-elements-selenium-python/#locate-element-by-xpath__

# %%
url = 'https://www.alkosto.com/'

# %%
Image(url= "https://www.guru99.com/images/3-2016/032816_0758_XPathinSele1.png")
# Out:
# <img src="https://www.guru99.com/images/3-2016/032816_0758_XPathinSele1.png"/>

# %%
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
browser.get(url)
#time.sleep(3)
texto_buscar = browser.find_element_by_xpath('//*[@id="search"]').send_keys("celulares"+"\n")
browser.maximize_window()

# %%
browser = webdriver.Chrome(executable_path=r"C:\chromedriver.exe")
 
browser.get(url)
#browser.maximize_window()
#time.sleep(3)
# El xpath de Computadores es:

boton_cat = browser.find_element_by_xpath('/html/body/div[1]/div[1]/div[1]/div/a[2]/em')
boton_cat.click()

# %%
browser.quit()

# %% [markdown]
# # Links Importantes:

# %% [markdown]
# 1. https://github.com/trembacz/xpath-finder <- Un Plugin para Chrome que permite encontrar de forma más sencilla el XPath de interés.
#
# 2. https://www.techbeamers.com/locate-elements-selenium-python/ <- Más información sobre tipos de localizadores.
#
# 3. https://towardsdatascience.com/web-scraping-using-selenium-python-8a60f4cf40ab <- Blog con más ejemplos de lo que vimos hoy.
