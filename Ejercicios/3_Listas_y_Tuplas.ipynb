# %% [markdown]
# 1. Haga un algoritmo que, utlizando listas, dibuje un rombo sin espacios entre los astericos y que funcione solo con números impares (si el usuario introduce un número par, le indique que debe ser impar y que lo vuelva a intentar).

# %%
numero= int(input("Introduzca un numero impar:" ))
while numero%2 == 0: 
             numero= int(input("El número debe ser un impar, intentelo de nuevo:" ))
s=[]
x= numero - 1
for i in range(numero+1):
    if i%2!=0: 
        s.append(i)
        print((" "*x)+ ()
# Out:
# Introduzca un numero impar:5
# [1]
# [1, 3]
# [1, 3, 5]

# %% [markdown]
# 2. Escriba un programa que permita crear una lista de palabras y que, a continuación, pida una palabra y diga cuántas veces aparece esa palabra en la lista.

# %%
n=int(input("Digame cuántas palabras tiene la lista: "))
x=1
palabras=[]
while n!=0: 
    palabra=input("Dígame la palabra número {}:".format(x))
    n=n-1
    palabras.append(palabra)
    x=x+1
print("Su lista de palabras es : {}". format(palabras))
contador=0
comparacion=input("Escriba la palabra que desea buscar: ")
for i in range(len(palabras)): 
    if comparacion == palabras[i]:
        contador= contador + 1


print("Su palabra aparece {} veces en su lista". format(contador))
# Out:
# Digame cuántas palabras tiene la lista: 4
# Dígame la palabra número 1:hola
# Dígame la palabra número 2:como
# Dígame la palabra número 3:como
# Dígame la palabra número 4:estas
# Su lista de palabras es : ['hola', 'como', 'como', 'estas']
# Escriba la palabra que desea buscar: como
# Su palabra aparece 2 veces en su lista

# %% [markdown]
# 3. Escribir un programa que almacene en una lista los siguientes precios, 50, 75, 46, 22, 80, 65, 8, y muestre por pantalla el menor y el mayor de los precios.

# %%
prices = [50, 75, 46, 22, 80, 65, 8]

menor= prices[0]
for i in range(len(prices)):
    if menor > prices[i]: 
        menor= prices[i]
print("El numero menor es {}".format(menor))
mayor= prices[0]
for i in range(len(prices)):
    if mayor < prices[i]: 
        mayor= prices[i]
print("El numero mayor es {}".format(mayor))
# Out:
# El numero menor es 8
# El numero mayor es 80

# %% [markdown]
# 4. Escribir un programa que pregunte por una muestra de números, separados por comas, los guarde en una lista y muestre por pantalla su media y desviación típica.

# %%
import statistics
muestra=input("Escriba una muestra, separados por coma: ")


muestra = muestra.replace(",", "")
muestra=list(muestra)
for i in range(len(muestra)):
    muestra[i]=int(muestra[i])

x=statistics.mean(muestra)
y=statistics.stdev(muestra)
print("La media es {}, y la desviacion tipica es {}".format(x,y))
# Out:
# Escriba una muestra, separados por coma: 2,3,4,5
# La media es 3.5, y la desviacion tipica es 1.2909944487358056
